# %%
# %cd /Users/johannesbreit/Library/CloudStorage/OneDrive-UniversityCollegeLondon/COMP0087/project/nlpproject
# Out:
# /Users/johannesbreit/Library/CloudStorage/OneDrive-UniversityCollegeLondon/COMP0087/project/nlpproject

# %%
import pandas as pd
import numpy as np
import re
import random
import os
import gzip
from collections import Counter, defaultdict, namedtuple

# %%
pwd
# Out:
# '/Users/johannesbreit/Library/CloudStorage/OneDrive-UniversityCollegeLondon/COMP0087/project/nlpproject'

# %%
ls
# Out:
# README.md         nlp/              requirements.txt

# %%
corpus_in = pd.read_csv('../nlpproject/nlp/data/example_inputs_pos_and_neg.tsv.gz', compression='gzip', header=0, sep='\t')
corpus_in.head()
# Out:
#                    entity1                     entity2  \
# 0                Apple Inc  Samsung Electronics Co Ltd
# 1        Bharti Airtel Ltd     Reliance Industries Ltd
# 2  Reliance Industries Ltd           Bharti Airtel Ltd
# 3        Bharti Airtel Ltd     Reliance Industries Ltd
# 4  Reliance Industries Ltd           Bharti Airtel Ltd
#
#                                                 left  \
# 0  \nThese reviews have been especially popular w...
# 1  * Q4 profit 829 mln rupees vs. 3.73 bln rupees...
# 2  \nThe entry of Reliance Jio, the telecoms arm of
# 3  The U.S. Supreme Court on Tuesday ruled that f...
# 4                                    REUTERS/Aziz Ta
#
#                                               middle  \
# 0                                      (AAPL.O) and
# 1   posted its lowest quarterly profit in nearly ...
# 2  , into India's telecoms sector has set off a b...
# 3  dan-based Arab Bank Plc helped finance militan...
# 4   Photo\nThe 5-4 decision brought to an end a l...
#
#                                                right  \
# 0   (005930.KS) frequently hit with patent infrin...
# 1   Jio, the telecoms arm of Reliance, into India...
# 2  's managing director and chief executive for I...
# 3                                          24, 2016.
# 4  minor connection between the terrorist attacks...
#
#                                              article  label
# 0  50b8f1a67bb7c2cab2fe56b55a24f59ad1703c07b7053e...      0
# 1  603eeb451da67a70850a823e4eb4e1221a5358040bde3b...      0
# 2  603eeb451da67a70850a823e4eb4e1221a5358040bde3b...      0
# 3  26cb6ec3607fdb028b712d260131058e9b01b9aadc26cf...      1
# 4  26cb6ec3607fdb028b712d260131058e9b01b9aadc26cf...      1

# %%
#Remove any \n from the rows 
corpus_in.replace("\n","",inplace=True)
corpus_in.replace('(\n)','',regex=True,inplace=True)
corpus_in.head()
# Out:
#                    entity1                     entity2  \
# 0                Apple Inc  Samsung Electronics Co Ltd
# 1        Bharti Airtel Ltd     Reliance Industries Ltd
# 2  Reliance Industries Ltd           Bharti Airtel Ltd
# 3        Bharti Airtel Ltd     Reliance Industries Ltd
# 4  Reliance Industries Ltd           Bharti Airtel Ltd
#
#                                                 left  \
# 0  These reviews have been especially popular wit...
# 1  * Q4 profit 829 mln rupees vs. 3.73 bln rupees...
# 2    The entry of Reliance Jio, the telecoms arm of
# 3  The U.S. Supreme Court on Tuesday ruled that f...
# 4                                    REUTERS/Aziz Ta
#
#                                               middle  \
# 0                                      (AAPL.O) and
# 1   posted its lowest quarterly profit in nearly ...
# 2  , into India's telecoms sector has set off a b...
# 3  dan-based Arab Bank Plc helped finance militan...
# 4   PhotoThe 5-4 decision brought to an end a law...
#
#                                                right  \
# 0   (005930.KS) frequently hit with patent infrin...
# 1   Jio, the telecoms arm of Reliance, into India...
# 2  's managing director and chief executive for I...
# 3                                          24, 2016.
# 4  minor connection between the terrorist attacks...
#
#                                              article  label
# 0  50b8f1a67bb7c2cab2fe56b55a24f59ad1703c07b7053e...      0
# 1  603eeb451da67a70850a823e4eb4e1221a5358040bde3b...      0
# 2  603eeb451da67a70850a823e4eb4e1221a5358040bde3b...      0
# 3  26cb6ec3607fdb028b712d260131058e9b01b9aadc26cf...      1
# 4  26cb6ec3607fdb028b712d260131058e9b01b9aadc26cf...      1

# %%
#Create sentences
df_data_sentences = corpus_in[['left', 'entity1', "middle",'entity2','right']].astype(str).agg(' '.join, axis=1)
corpus_in['sentences'] = df_data_sentences.values
corpus_in.head()
# Out:
#                    entity1                     entity2  \
# 0                Apple Inc  Samsung Electronics Co Ltd
# 1        Bharti Airtel Ltd     Reliance Industries Ltd
# 2  Reliance Industries Ltd           Bharti Airtel Ltd
# 3        Bharti Airtel Ltd     Reliance Industries Ltd
# 4  Reliance Industries Ltd           Bharti Airtel Ltd
#
#                                                 left  \
# 0  These reviews have been especially popular wit...
# 1  * Q4 profit 829 mln rupees vs. 3.73 bln rupees...
# 2    The entry of Reliance Jio, the telecoms arm of
# 3  The U.S. Supreme Court on Tuesday ruled that f...
# 4                                    REUTERS/Aziz Ta
#
#                                               middle  \
# 0                                      (AAPL.O) and
# 1   posted its lowest quarterly profit in nearly ...
# 2  , into India's telecoms sector has set off a b...
# 3  dan-based Arab Bank Plc helped finance militan...
# 4   PhotoThe 5-4 decision brought to an end a law...
#
#                                                right  \
# 0   (005930.KS) frequently hit with patent infrin...
# 1   Jio, the telecoms arm of Reliance, into India...
# 2  's managing director and chief executive for I...
# 3                                          24, 2016.
# 4  minor connection between the terrorist attacks...
#
#                                              article  label  \
# 0  50b8f1a67bb7c2cab2fe56b55a24f59ad1703c07b7053e...      0
# 1  603eeb451da67a70850a823e4eb4e1221a5358040bde3b...      0
# 2  603eeb451da67a70850a823e4eb4e1221a5358040bde3b...      0
# 3  26cb6ec3607fdb028b712d260131058e9b01b9aadc26cf...      1
# 4  26cb6ec3607fdb028b712d260131058e9b01b9aadc26cf...      1
#
#                                            sentences
# 0  These reviews have been especially popular wit...
# 1  * Q4 profit 829 mln rupees vs. 3.73 bln rupees...
# 2  The entry of Reliance Jio, the telecoms arm of...
# 3  The U.S. Supreme Court on Tuesday ruled that f...
# 4  REUTERS/Aziz Ta Reliance Industries Ltd  Photo...

# %%
kb_df = pd.read_csv('../nlpproject/nlp/data/example_kb_all_supplier.tsv.gz', compression='gzip', 
                                 names= ['relation', 'subject', 'object'], sep='\t', quotechar='"')

# %%
kb_df.head()
# Out:
#       relation                            subject                      object
# 0  supplier of                          Apple Inc  Seoul Semiconductor Co Ltd
# 1  supplier of  Koizumi furnitech Thailand Co Ltd  Seoul Semiconductor Co Ltd
# 2  supplier of                     Amazon.com Inc                DS Smith PLC
# 3  supplier of                Procter & Gamble Co                DS Smith PLC
# 4  supplier of                      Zymeworks Inc                DS Smith PLC

# %%
def stanford_split(kb, corpus, split_ratios = [0.6, 0.2, 0.2], verbose = False):
    
    assert sum(split_ratios) == 1, 'Split Ratios do not add up to 1'

    # Randomly split the subjects in the KB between train/dev/test splits 
    # TODO: Random number generation split does not create exact splits - make this exact with length split instead (but works for now)
    def subject_split(kb, split_ratios):
        subjects = pd.DataFrame(kb.subject.unique()).rename(columns = {0: 'subject'})
        subjects['split'] = [np.random.choice(3, p =  split_ratios) for _ in range(len(subjects))] 
        return subjects

    if verbose: pass

    # Merge split numbers for subjects (E1) back onto kb df
    kb_with_splits = kb_df.merge(subject_split(kb, split_ratios), how = 'left', on = 'subject')

    split_dict = {sbj: split for sbj, split in zip(kb_with_splits.subject, kb_with_splits.split)}

    corpus_with_splits = corpus.copy()

    # Use stanford Rule:
    # If E1 in corpus in a KB split -> place sentence to that split.
    # Else if E2 in corpus in a KB split -> place sentance to that split.
    # If neither of above, assign sentence to random split.
    splits = []
    count_not_matched = 0
    for E1, E2 in zip(corpus_with_splits.entity1, corpus_with_splits.entity2): 
        if E1 in split_dict.keys():
            splits.append(split_dict[E1])
        elif E2 in split_dict.keys():
            splits.append(split_dict[E2])
        else:
            splits.append(np.random.choice(3, p = split_ratios))
            if verbose: print('{}, {} not in KB split' .format(E1, E2))
            count_not_matched += 1
    print('Total of {} entries in corpus not matched to KB. \n' .format(count_not_matched))
    corpus_with_splits['split'] = splits

    # if verbose:
    print('KB split ratios: \n {} \n' .format(kb_with_splits.split.value_counts(normalize = True)))
    print('Corpus split ratios: \n {} \n' .format(corpus_with_splits.split.value_counts(normalize = True)))

    return kb_with_splits, corpus_with_splits

# %%
kb_split, corpus_split = stanford_split(kb_df, corpus_in)
# Out:
# Total of 38 entries in corpus not matched to KB.
#
# KB split ratios:
#  0    0.575583
# 1    0.213867
# 2    0.210550
# Name: split, dtype: float64
#
# Corpus split ratios:
#  0    0.546038
# 1    0.262683
# 2    0.191279
# Name: split, dtype: float64

# %%
kb_split
# Out:
#           relation                            subject  \
# 0      supplier of                          Apple Inc
# 1      supplier of  Koizumi furnitech Thailand Co Ltd
# 2      supplier of                     Amazon.com Inc
# 3      supplier of                Procter & Gamble Co
# 4      supplier of                      Zymeworks Inc
# ...            ...                                ...
# 18081  supplier of     Cisco Systems Inc (Pre-Merger)
# 18082  supplier of     Cisco Systems Inc (Pre-Merger)
# 18083  supplier of     Cisco Systems Inc (Pre-Merger)
# 18084  supplier of     Cisco Systems Inc (Pre-Merger)
# 18085  supplier of     Cisco Systems Inc (Pre-Merger)
#
#                            object  split
# 0      Seoul Semiconductor Co Ltd      0
# 1      Seoul Semiconductor Co Ltd      1
# 2                    DS Smith PLC      1
# 3                    DS Smith PLC      0
# 4                    DS Smith PLC      0
# ...                           ...    ...
# 18081     Synetrix (Holdings) Ltd      0
# 18082                Servcorp Ltd      0
# 18083             SolarWinds Corp      0
# 18084  Unified Communications Ltd      0
# 18085          Verint Systems Inc      0
#
# [18086 rows x 4 columns]

# %%
kb_split.split.value_counts(normalize = False), kb_split.split.value_counts(normalize = True)
# Out:
# (0    10410
#  1     3868
#  2     3808
#  Name: split, dtype: int64,
#  0    0.575583
#  1    0.213867
#  2    0.210550
#  Name: split, dtype: float64)

# %%
corpus_split.split.value_counts(), corpus_split.split.value_counts(normalize=True)
# Out:
# (0    47122
#  1    22669
#  2    16507
#  Name: split, dtype: int64,
#  0    0.546038
#  1    0.262683
#  2    0.191279
#  Name: split, dtype: float64)

# %%
kb_split[kb_split.subject.astype(str).str.contains('Apple')]
# Out:
#           relation    subject                           object  split
# 0      supplier of  Apple Inc       Seoul Semiconductor Co Ltd      0
# 44     supplier of  Apple Inc                         TDK Corp      0
# 139    supplier of  Apple Inc               LG Electronics Inc      0
# 142    supplier of  Apple Inc            Cowell e Holdings Inc      0
# 234    supplier of  Apple Inc  Coxon Precise Industrial Co Ltd      0
# ...            ...        ...                              ...    ...
# 14669  supplier of  Apple Inc                    Samsung Group      0
# 14670  supplier of  Apple Inc              Global Unichip Corp      0
# 14671  supplier of  Apple Inc              Electronic Arts Inc      0
# 14672  supplier of  Apple Inc     Pelephone Communications Ltd      0
# 14673  supplier of  Apple Inc           Tile Shop Holdings Inc      0
#
# [321 rows x 4 columns]

# %%
corpus_split[corpus_split.entity1.astype(str).str.contains('Apple')]
# Out:
#          entity1                     entity2  \
# 0      Apple Inc  Samsung Electronics Co Ltd
# 21     Apple Inc              Amazon.com Inc
# 25     Apple Inc                 Corning Inc
# 26     Apple Inc                 Netflix Inc
# 30     Apple Inc                 Corning Inc
# ...          ...                         ...
# 86275  Apple Inc  Samsung Electronics Co Ltd
# 86282  Apple Inc  Huawei Technologies Co Ltd
# 86283  Apple Inc  Samsung Electronics Co Ltd
# 86289  Apple Inc              Amazon.com Inc
# 86292  Apple Inc              Amazon.com Inc
#
#                                                     left  \
# 0      These reviews have been especially popular wit...
# 21
# 25
# 26
# 30                                   At least two other
# ...                                                  ...
# 86275       "Xiaomi has a different business model than
# 86282  But small players compete for just one-fifth o...
# 86283  But small players compete for just one-fifth o...
# 86289  The showing is a chance for Google and Microso...
# 86292  The showing is a chance for Google and Microso...
#
#                                                   middle  \
# 0                                          (AAPL.O) and
# 21      shares lost {AAPL.O;-PCTCHNG:2} percent as wo...
# 25      shares lost {AAPL.O;-PCTCHNG:2} percent as wo...
# 26      shares lost {AAPL.O;-PCTCHNG:2} percent as wo...
# 30      suppliers - contract chipmaker Taiwan (2330.T...
# ...                                                  ...
# 86275                                                or
# 86282                          , Samsung, Lenovo Group,
# 86283                                                 ,
# 86289                                                 ,
# 86292                                         (AAPL.O),
#
#                                                    right  \
# 0       (005930.KS) frequently hit with patent infrin...
# 21              and Netflix, also weighed on the Nasdaq.
# 25      reported a drop in screen glass sales for the...
# 26                         , also weighed on the Nasdaq.
# 30      said net sales in its specialty materials bus...
# ...                                                  ...
# 86275  ," said Ben Thompson, founder of Stratechery.c...
# 86282        [HWT.UL] and Xiaomi - according to Gartner.
# 86283  , Lenovo Group, Huawei [HWT.UL] and Xiaomi - a...
# 86289   and cable and satellite operators, to raise t...
# 86292   (AMZN.O) and cable and satellite operators, t...
#
#                                                  article  label  \
# 0      50b8f1a67bb7c2cab2fe56b55a24f59ad1703c07b7053e...      0
# 21     90ce5e433c2f36e596ecc077cc8d101da1e52fbbfe8f60...      0
# 25     90ce5e433c2f36e596ecc077cc8d101da1e52fbbfe8f60...      1
# 26     90ce5e433c2f36e596ecc077cc8d101da1e52fbbfe8f60...      0
# 30     d70b8e93655d2bcfe4d17991e8d6a3a6ef5b8bd6b86d55...      1
# ...                                                  ...    ...
# 86275  314f65ec6b5b415077196cf630f4610077090b206a215c...      0
# 86282  f1adc11d5bb922a82100ef54cf12f8e155920e66870d1a...      1
# 86283  f1adc11d5bb922a82100ef54cf12f8e155920e66870d1a...      0
# 86289  c47e4f5ae80aca73dc67ea032a9ada5c96c1f1e1db103e...      0
# 86292  5ebe8ed41ddfb003b44e24135a68a3583f4871a7f9f2fb...      0
#
#                                                sentences  split
# 0      These reviews have been especially popular wit...      0
# 21      Apple Inc  shares lost {AAPL.O;-PCTCHNG:2} pe...      0
# 25      Apple Inc  shares lost {AAPL.O;-PCTCHNG:2} pe...      0
# 26      Apple Inc  shares lost {AAPL.O;-PCTCHNG:2} pe...      0
# 30     At least two other  Apple Inc  suppliers - con...      0
# ...                                                  ...    ...
# 86275  "Xiaomi has a different business model than  A...      0
# 86282  But small players compete for just one-fifth o...      0
# 86283  But small players compete for just one-fifth o...      0
# 86289  The showing is a chance for Google and Microso...      0
# 86292  The showing is a chance for Google and Microso...      0
#
# [10110 rows x 9 columns]

# %% [markdown]
# # Method 2

# %%
corpus_test = corpus_in.copy()

corpus_test['relation_tuple'] = [tuple(sorted([E1, E2])) for E1, E2 in zip(corpus_test.entity1, corpus_test.entity2)]
corpus_test.head()
# Out:
#                    entity1                     entity2  \
# 0                Apple Inc  Samsung Electronics Co Ltd
# 1        Bharti Airtel Ltd     Reliance Industries Ltd
# 2  Reliance Industries Ltd           Bharti Airtel Ltd
# 3        Bharti Airtel Ltd     Reliance Industries Ltd
# 4  Reliance Industries Ltd           Bharti Airtel Ltd
#
#                                                 left  \
# 0  These reviews have been especially popular wit...
# 1  * Q4 profit 829 mln rupees vs. 3.73 bln rupees...
# 2    The entry of Reliance Jio, the telecoms arm of
# 3  The U.S. Supreme Court on Tuesday ruled that f...
# 4                                    REUTERS/Aziz Ta
#
#                                               middle  \
# 0                                      (AAPL.O) and
# 1   posted its lowest quarterly profit in nearly ...
# 2  , into India's telecoms sector has set off a b...
# 3  dan-based Arab Bank Plc helped finance militan...
# 4   PhotoThe 5-4 decision brought to an end a law...
#
#                                                right  \
# 0   (005930.KS) frequently hit with patent infrin...
# 1   Jio, the telecoms arm of Reliance, into India...
# 2  's managing director and chief executive for I...
# 3                                          24, 2016.
# 4  minor connection between the terrorist attacks...
#
#                                              article  label  \
# 0  50b8f1a67bb7c2cab2fe56b55a24f59ad1703c07b7053e...      0
# 1  603eeb451da67a70850a823e4eb4e1221a5358040bde3b...      0
# 2  603eeb451da67a70850a823e4eb4e1221a5358040bde3b...      0
# 3  26cb6ec3607fdb028b712d260131058e9b01b9aadc26cf...      1
# 4  26cb6ec3607fdb028b712d260131058e9b01b9aadc26cf...      1
#
#                                            sentences  \
# 0  These reviews have been especially popular wit...
# 1  * Q4 profit 829 mln rupees vs. 3.73 bln rupees...
# 2  The entry of Reliance Jio, the telecoms arm of...
# 3  The U.S. Supreme Court on Tuesday ruled that f...
# 4  REUTERS/Aziz Ta Reliance Industries Ltd  Photo...
#
#                                  relation_tuple
# 0       (Apple Inc, Samsung Electronics Co Ltd)
# 1  (Bharti Airtel Ltd, Reliance Industries Ltd)
# 2  (Bharti Airtel Ltd, Reliance Industries Ltd)
# 3  (Bharti Airtel Ltd, Reliance Industries Ltd)
# 4  (Bharti Airtel Ltd, Reliance Industries Ltd)

# %%
corpus_counts = corpus_test.groupby(['relation_tuple']).agg('size').reset_index().sort_values(by = 0, ascending=False).rename(columns = {0: 'sentence_counts'})
corpus_counts
# Out:
#                                        relation_tuple  sentence_counts
# 1248          (Apple Inc, Samsung Electronics Co Ltd)             2962
# 814                       (Amazon.com Inc, Apple Inc)             2156
# 1202                      (Apple Inc, Microsoft Corp)             2052
# 3110               (Ford Motor Co, General Motors Co)             1380
# 1230                        (Apple Inc, Qualcomm Inc)             1275
# ...                                               ...              ...
# 3796      (Hyundai Motor Co, Korean Air Lines Co Ltd)                1
# 1549  (Baker Hughes Co, United Airlines Holdings Inc)                1
# 1548         (Baker Hughes Co, Texas Instruments Inc)                1
# 1545         (Baker Hughes Co, Rivian Automotive Inc)                1
# 5630                           (Xilinx Inc, eBay Inc)                1
#
# [5631 rows x 2 columns]

# %%
print(corpus_counts.sentence_counts.sum())

data_split = np.array([0.6,0.2,0.2])

counts_per_split = corpus_counts.sentence_counts.sum() * data_split

counts_per_split
# Out:
# 86298
# array([51778.8, 17259.6, 17259.6])

# %%
# Shuffle this to get rid of numerical order 
shuffled_corpus_counts = corpus_counts.sample(frac=1)

# %%
shuffled_corpus_counts['sentence_cumsum'] = np.cumsum(shuffled_corpus_counts.sentence_counts)

# %%
shuffled_corpus_counts.head()
# Out:
#                                   relation_tuple  sentence_counts  \
# 4982                (Panasonic Corp, Xilinx Inc)                2
# 4136         (Kobe Steel Ltd, Nippon Steel Corp)                5
# 1079          (Anadarko Petroleum Corp, VF Corp)                1
# 4786      (Nestle SA, United Parcel Service Inc)                1
# 5076  (Qorvo Inc, Spreadtrum Communications Inc)                1
#
#       sentence_cumsum
# 4982                2
# 4136                7
# 1079                8
# 4786                9
# 5076               10

# %%
counts_cumsum = counts_per_split.cumsum()
counts_cumsum
# Out:
# array([51778.8, 69038.4, 86298. ])

# %%
splits = []
for scs in shuffled_corpus_counts.sentence_cumsum:
    if scs <= counts_cumsum[0]:
        splits.append(0)
    elif scs > counts_cumsum[0] and scs <= counts_cumsum[1]:
        splits.append(1)
    else: 
        splits.append(2)
shuffled_corpus_counts['split'] = splits

print(shuffled_corpus_counts.groupby('split').sum(), shuffled_corpus_counts.groupby('split').size())

shuffled_corpus_counts.head()
# Out:
#        sentence_counts  sentence_cumsum
# split
# 0                51776         76395382
# 1                17178         74317464
# 2                17344        107116774 split
# 0    3025
# 1    1233
# 2    1373
# dtype: int64
#                                   relation_tuple  sentence_counts  \
# 4982                (Panasonic Corp, Xilinx Inc)                2
# 4136         (Kobe Steel Ltd, Nippon Steel Corp)                5
# 1079          (Anadarko Petroleum Corp, VF Corp)                1
# 4786      (Nestle SA, United Parcel Service Inc)                1
# 5076  (Qorvo Inc, Spreadtrum Communications Inc)                1
#
#       sentence_cumsum  split
# 4982                2      0
# 4136                7      0
# 1079                8      0
# 4786                9      0
# 5076               10      0

# %%
corpus_test = corpus_test.merge(shuffled_corpus_counts, how = 'left', on = 'relation_tuple')

corpus_test.head(5)
# Out:
#                    entity1                     entity2  \
# 0                Apple Inc  Samsung Electronics Co Ltd
# 1        Bharti Airtel Ltd     Reliance Industries Ltd
# 2  Reliance Industries Ltd           Bharti Airtel Ltd
# 3        Bharti Airtel Ltd     Reliance Industries Ltd
# 4  Reliance Industries Ltd           Bharti Airtel Ltd
#
#                                                 left  \
# 0  These reviews have been especially popular wit...
# 1  * Q4 profit 829 mln rupees vs. 3.73 bln rupees...
# 2    The entry of Reliance Jio, the telecoms arm of
# 3  The U.S. Supreme Court on Tuesday ruled that f...
# 4                                    REUTERS/Aziz Ta
#
#                                               middle  \
# 0                                      (AAPL.O) and
# 1   posted its lowest quarterly profit in nearly ...
# 2  , into India's telecoms sector has set off a b...
# 3  dan-based Arab Bank Plc helped finance militan...
# 4   PhotoThe 5-4 decision brought to an end a law...
#
#                                                right  \
# 0   (005930.KS) frequently hit with patent infrin...
# 1   Jio, the telecoms arm of Reliance, into India...
# 2  's managing director and chief executive for I...
# 3                                          24, 2016.
# 4  minor connection between the terrorist attacks...
#
#                                              article  label  \
# 0  50b8f1a67bb7c2cab2fe56b55a24f59ad1703c07b7053e...      0
# 1  603eeb451da67a70850a823e4eb4e1221a5358040bde3b...      0
# 2  603eeb451da67a70850a823e4eb4e1221a5358040bde3b...      0
# 3  26cb6ec3607fdb028b712d260131058e9b01b9aadc26cf...      1
# 4  26cb6ec3607fdb028b712d260131058e9b01b9aadc26cf...      1
#
#                                            sentences  \
# 0  These reviews have been especially popular wit...
# 1  * Q4 profit 829 mln rupees vs. 3.73 bln rupees...
# 2  The entry of Reliance Jio, the telecoms arm of...
# 3  The U.S. Supreme Court on Tuesday ruled that f...
# 4  REUTERS/Aziz Ta Reliance Industries Ltd  Photo...
#
#                                  relation_tuple  sentence_counts  \
# 0       (Apple Inc, Samsung Electronics Co Ltd)             2962
# 1  (Bharti Airtel Ltd, Reliance Industries Ltd)               36
# 2  (Bharti Airtel Ltd, Reliance Industries Ltd)               36
# 3  (Bharti Airtel Ltd, Reliance Industries Ltd)               36
# 4  (Bharti Airtel Ltd, Reliance Industries Ltd)               36
#
#    sentence_cumsum  split
# 0            40604      0
# 1            15659      0
# 2            15659      0
# 3            15659      0
# 4            15659      0

# %%
kb_test = kb_df.copy()
kb_test['relation_tuple'] = [tuple(sorted([E1, E2])) for E1, E2 in zip(kb_test.subject.astype(str), kb_test.object.astype(str))]

kb_test = kb_test.merge(corpus_test[['relation_tuple', 'split']], how = 'left', on = 'relation_tuple')

print(kb_test.split.value_counts(dropna=False, ascending = True))

kb_test[kb_test.subject == 'Apple Inc']
# Out:
# 2.0    15049
# NaN    16455
# 1.0    16494
# 0.0    35902
# Name: split, dtype: int64
#           relation    subject                        object  \
# 0      supplier of  Apple Inc    Seoul Semiconductor Co Ltd
# 158    supplier of  Apple Inc                      TDK Corp
# 159    supplier of  Apple Inc                      TDK Corp
# 160    supplier of  Apple Inc                      TDK Corp
# 161    supplier of  Apple Inc                      TDK Corp
# ...            ...        ...                           ...
# 78457  supplier of  Apple Inc                 Samsung Group
# 78458  supplier of  Apple Inc           Global Unichip Corp
# 78459  supplier of  Apple Inc           Electronic Arts Inc
# 78460  supplier of  Apple Inc  Pelephone Communications Ltd
# 78461  supplier of  Apple Inc        Tile Shop Holdings Inc
#
#                                   relation_tuple  split
# 0        (Apple Inc, Seoul Semiconductor Co Ltd)    NaN
# 158                        (Apple Inc, TDK Corp)    2.0
# 159                        (Apple Inc, TDK Corp)    2.0
# 160                        (Apple Inc, TDK Corp)    2.0
# 161                        (Apple Inc, TDK Corp)    2.0
# ...                                          ...    ...
# 78457                 (Apple Inc, Samsung Group)    1.0
# 78458           (Apple Inc, Global Unichip Corp)    NaN
# 78459           (Apple Inc, Electronic Arts Inc)    0.0
# 78460  (Apple Inc, Pelephone Communications Ltd)    NaN
# 78461        (Apple Inc, Tile Shop Holdings Inc)    NaN
#
# [9822 rows x 5 columns]

# %%
corpus_test[corpus_test.relation_tuple == ('Apple Inc', 'TDK Corp')]
# Out:
#          entity1    entity2  \
# 7758   Apple Inc   TDK Corp
# 7759    TDK Corp  Apple Inc
# 8358   Apple Inc   TDK Corp
# 17221  Apple Inc   TDK Corp
# 17447  Apple Inc   TDK Corp
# 17762  Apple Inc   TDK Corp
# 21167  Apple Inc   TDK Corp
# 26104  Apple Inc   TDK Corp
# 26268  Apple Inc   TDK Corp
# 26512  Apple Inc   TDK Corp
# 26513   TDK Corp  Apple Inc
# 34913  Apple Inc   TDK Corp
# 35019  Apple Inc   TDK Corp
# 52322  Apple Inc   TDK Corp
# 52419  Apple Inc   TDK Corp
# 52478  Apple Inc   TDK Corp
# 52536  Apple Inc   TDK Corp
# 52537   TDK Corp  Apple Inc
# 52637  Apple Inc   TDK Corp
# 52755   TDK Corp  Apple Inc
# 57940  Apple Inc   TDK Corp
# 64803  Apple Inc   TDK Corp
# 64804  Apple Inc   TDK Corp
# 65293  Apple Inc   TDK Corp
# 65294   TDK Corp  Apple Inc
# 66773  Apple Inc   TDK Corp
# 71045   TDK Corp  Apple Inc
# 76055   TDK Corp  Apple Inc
# 83458  Apple Inc   TDK Corp
# 83936   TDK Corp  Apple Inc
#
#                                                     left  \
# 7758                                           Japanese
# 7759        Japanese Apple suppliers outperformed, with
# 8358
# 17221  Apple suppliers were sold after the Nikkei bus...
# 17447  Apple suppliers were sold after the Nikkei bus...
# 17762  The San Jose, California-based startup was fou...
# 21167                                          In turn,
# 26104               Technology firms were buoyant after
# 26268                               In Japan, shares of
# 26512                                           Another
# 26513                            Another Apple supplier
# 34913  TOKYO, Oct 27 (Reuters) - Tokyo stocks fell on...
# 35019
# 52322                                Parts suppliers to
# 52419                                 Stocks related to
# 52478                                             Among
# 52536  AN APPLE A DAYThursday's rise was also partly ...
# 52537
# 52637     Japan's technology companies that are part of
# 52755                                                NaN
# 57940              Murata, which supplies components to
# 64803                                      Tokyo-listed
# 64804      Taking positive cues from this, Tokyo-listed
# 65293                                          In turn,
# 65294  Japan Display sank 9.5 percent, Murata Manufac...
# 66773                                      Tokyo-listed
# 71045  Tokyo Electron rallied 3.2 percent, Kyocera Co...
# 76055                                                NaN
# 83458                            The results weighed on
# 83936     Japanese electronic components makers such as
#
#                                                   middle  \
# 7758                       suppliers outperformed, with
# 7759    gaining 0.7 percent and Foster Electric risin...
# 8358    told investors late on Monday that its manufa...
# 17221   has told its smartphone assemblers Foxconn an...
# 17447   had told its smartphone assemblers Foxconn an...
# 17762       and others before being acquired by Japan's
# 21167  -linked shares in Tokyo retreated. Japan Displ...
# 26104  's March quarter results topped Wall Street fo...
# 26268   suppliers surged. Murata Manufacturing gained...
# 26512                                          supplier
# 26513  , which is scheduled to report its quarterly e...
# 34913                                 suppliers such as
# 35019  's component suppliers slid after Morgan Stanl...
# 52322   were in demand after the U.S. company unveile...
# 52419  , such as component suppliers, tumbled after t...
# 52478   suppliers, Nitto Denko Corp dropped 4.5 perce...
# 52536   (AAPL.O) component suppliers after the iPhone...
# 52537   (6762.T) advanced 3.7 percent, with traders s...
# 52637  's (AAPL.O) supply chain gained broadly after ...
# 52755   dropped 1.1 percent and Hitachi Ltd shed 1.3 ...
# 57940   , Nokia and most major automakers, said it wi...
# 64803  -related shares were in demand on Tuesday. Mur...
# 64804  -related electronic parts makers and chip-rela...
# 65293  -linked shares in Tokyo retreated. Japan Displ...
# 65294   lost 6.2 percent.Other technology shares also...
# 66773  -related shares were also in demand on Tuesday...
# 71045   advanced 2.5 percent.Nintendo Co jumped 5 per...
# 76055   dropped 1.1 percent and Hitachi Ltd shed 1.3 ...
# 83458  's Japanese suppliers, with Alps Electric Co L...
# 83936   and Murata Manufacturing (6981.T) prospered i...
#
#                                                    right  \
# 7758    gaining 0.7 percent and Foster Electric risin...
# 7759    rose 3.6 percent on Friday after it quashed c...
# 8358                                          sank 4.2%.
# 17221   shed 2 percent and Nitto Denko dropped 1.3 pe...
# 17447   shed 1.9 percent and Nitto Denko dropped 2.5 ...
# 17762                    for about $1.3 billion in 2016.
# 21167                                  lost 8.2 percent.
# 26104   climbed 0.8 percent and industrial tape and L...
# 26268                                 added 2.8 percent.
# 26512  , which is scheduled to report its quarterly e...
# 26513  's performance in the Oct-Dec period receded, ...
# 34913   and Murata Manufacturing Co tumbled before th...
# 35019   tumbled 3.9 percent, Murata Manufacturing Co ...
# 52322  , which surged 6.6 percent on Wednesday on a b...
# 52419                              declined 2.6 percent.
# 52478                                  fell 4.1 percent.
# 52536   (6762.T) advanced 3.7 percent, with traders s...
# 52537                                                  .
