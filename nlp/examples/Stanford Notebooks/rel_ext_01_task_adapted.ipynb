# %% [markdown]
# # Relation extraction using distant supervision: task definition

# %%
__author__ = "Bill MacCartney and Christopher Potts"
__version__ = "CS224u, Stanford, Spring 2021"

# %% [markdown]
# ## Contents
#
# 1. [Overview](#Overview)
#   1. [The task of relation extraction](#The-task-of-relation-extraction)
#   1. [Hand-built patterns](#Hand-built-patterns)
#   1. [Supervised learning](#Supervised-learning)
#   1. [Distant supervision](#Distant-supervision)
# 1. [Set-up](#Set-up)
# 1. [The corpus](#The-corpus)
# 1. [The knowledge base](#The-knowledge-base)
# 1. [Problem formulation](#Problem-formulation)
#   1. [Joining the corpus and the KB](#Joining-the-corpus-and-the-KB)
#   1. [Negative instances](#Negative-instances)
#   1. [Multi-label classification](#Multi-label-classification)
#   1. [Building datasets](#Building-datasets)
# 1. [Evaluation](#Evaluation)
#   1. [Splitting the data](#Splitting-the-data)
#   1. [Choosing evaluation metrics](#Choosing-evaluation-metrics)
#   1. [Running evaluations](#Running-evaluations)
#   1. [Evaluating a random-guessing strategy](#Evaluating-a-random-guessing-strategy)
# 1. [A simple baseline model](#A-simple-baseline-model)

# %% [markdown]
# ## Overview
#
# This notebook illustrates an approach to [relation extraction](http://deepdive.stanford.edu/relation_extraction) using [distant supervision](http://deepdive.stanford.edu/distant_supervision). It uses a simplified version of the approach taken by Mintz et al. in their 2009 paper, [Distant supervision for relation extraction without labeled data](https://www.aclweb.org/anthology/P09-1113). If you haven't yet read that paper, read it now! The rest of the notebook will make a lot more sense after you're familiar with it.
#
# ### The task of relation extraction
#
# Relation extraction is the task of extracting from natural language text relational triples such as:
#
# ```
# (founders, SpaceX, Elon_Musk)
# (has_spouse, Elon_Musk, Talulah_Riley)
# (worked_at, Elon_Musk, Tesla_Motors)
# ```
#
# If we can accumulate a large knowledge base (KB) of relational triples, we can use it to power question answering and other applications. Building a KB manually is slow and expensive, but much of the knowledge we'd like to capture is already expressed in abundant text on the web. The aim of relation extraction, therefore, is to accelerate the construction of new KBs — and facilitate the ongoing curation of existing KBs — by extracting relational triples from natural language text.
#
# ### Hand-built patterns
#
# An obvious way to start is to write down a few patterns which express each relation. For example, we can use the pattern "X is the founder of Y" to find new instances of the `founders` relation. If we search a large corpus, we may find the phrase "Elon Musk is the founder of SpaceX", which we can use as evidence for the relational triple `(founders, SpaceX, Elon_Musk)`.
#
# Unfortunately, this approach doesn't get us very far. The central challenge of relation extraction is the fantastic diversity of language, the multitude of possible ways to express a given relation. For example, each of the following sentences expresses the relational triple `(founders, SpaceX, Elon_Musk)`:
#
# - "You may also be thinking of *Elon Musk* (founder of *SpaceX*), who started PayPal."
# - "Interesting Fact: *Elon Musk*, co-founder of PayPal, went on to establish *SpaceX*, one of the most promising space travel startups in the world."
# - "If Space Exploration (*SpaceX*), founded by Paypal pioneer *Elon Musk* succeeds, commercial advocates will gain credibility and more support in Congress."
#
# The patterns which connect "Elon Musk" with "SpaceX" in these examples are not ones we could have easily anticipated. To do relation extraction effectively, we need to go beyond hand-built patterns.
#
# ### Supervised learning
#
# Effective relation extraction will require applying machine learning methods. The natural place to start is with supervised learning. This means training an extraction model from a dataset of examples which have been labeled with the target output. Sentences like the three examples above would be annotated with the `founders` relation, but we'd also have sentences which include "Elon Musk" and "SpaceX" but do not express the `founders` relation, such as:
#
# - "Billionaire entrepreneur *Elon Musk* announced the latest addition to the *SpaceX* arsenal: the 'Big F---ing Rocket' (BFR)".
#
# Such "negative examples" would be labeled as such, and the fully-supervised model would then be able to learn from both positive and negative examples the linguistic patterns that indicate each relation.
#
# The difficulty with the fully-supervised approach is the cost of generating training data. Because of the great diversity of linguistic expression, our model will need lots and lots of training data: at least tens of thousands of examples, although hundreds of thousands or millions would be much better. But labeling the examples is just as slow and expensive as building the KB by hand would be.
#
# ### Distant supervision
#
# The goal of distant supervision is to capture the benefits of supervised learning without paying the cost of labeling training data. Instead of labeling extraction examples by hand, we use existing relational triples to automatically identify extraction examples in a large corpus. For example, if we already have in our KB the relational triple `(founders, SpaceX, Elon_Musk)`, we can search a large corpus for sentences in which "SpaceX" and "Elon Musk" co-occur, make the (unreliable!) assumption that all the sentences express the `founder` relation, and then use them as training data for a learned model to identify new instances of the `founder` relation — all without doing any manual labeling.
#
# This is a powerful idea, but it has two limitations. The first is that, inevitably, some of the sentences in which "SpaceX" and "Elon Musk" co-occur will not express the `founder` relation — like the BFR example above. By making the blind assumption that all such sentences do express the `founder` relation, we are essentially injecting noise into our training data, and making it harder for our learning algorithms to learn good models. Distant supervision is effective in spite of this problem because it makes it possible to leverage vastly greater quantities of training data, and the benefit of more data outweighs the harm of noisier data.
#
# The second limitation is that we need an existing KB to start from. We can only train a model to extract new instances of the `founders` relation if we already have many instances of the `founders` relation. Thus, while distant supervision is a great way to extend an existing KB, it's not useful for creating a KB containing new relations from scratch.
#
# \[ [top](#Relation-extraction-using-distant-supervision:-task-definition) \]

# %% [markdown]
# ## Set-up
#
# *  Make sure your environment includes all the requirements for [the cs224u repository](https://github.com/cgpotts/cs224u).
#
# * If you haven't already, download [the course data](http://web.stanford.edu/class/cs224u/data/data.tgz), unpack it, and place it in the directory containing the course repository – the same directory as this notebook. (If you want to put it somewhere else, change `rel_ext_data_home` below.)

# %% [markdown]
# # Make sure the files 'example_inputs_long_names.tsv.gz' and 'example_kb.tsv.gz' are in the data folder. These are created using the value_chain_data_exploration notebook in the examples folder

# %%
import random
import os
from collections import Counter, defaultdict
import rel_ext
import utils
import sys

# %%
# Set all the random seeds for reproducibility. Only the
# system seed is relevant for this notebook.

utils.fix_random_seeds()

# %%
try:
    # python package (nlp) location - two levels up from this file
    src_path = os.path.abspath(os.path.join(os.getcwd(), "../.."))
    # add package to sys.path if it's not already there
    if src_path not in sys.path:
        sys.path.extend([src_path])
except NameError:
    print('issue with adding to path, probably due to __file__ not being defined')
    src_path = None

# %%
rel_ext_data_home = os.path.join(src_path,'data')
rel_ext_data_home
# Out:
# '/Users/timmaecker/Google Drive/Career and Skills/Learning/MSc Machine Learning - UCL/2 COMP0087 Statistical Natural Language Processing/Coursework/nlpproject/nlp/data'

# %% [markdown]
# ## The corpus

# %% [markdown]
# As usual when we're doing NLP, we need to start with a _corpus_ — a large sample of natural language text. And because our goal is to do relation extraction with distant supervision, we need to be able to identify entities in the text and connect them to a knowledge base of relations between entities. So, we need a corpus in which entity mentions are annotated with _entity resolutions_ which map them to unique, unambiguous identifiers. Entity resolution serves two purposes:
#
# 1. It ensures that if an entity mention could refer to two different entities, it is properly disambiguated. For example, "New York" could refer to the city or the state.
# 1. It ensures that if two different entity mentions refer to the same entity, they are properly identified. For example, both "New York City" and "The Big Apple" refer to New York City.
#
# The corpus we'll use for this project is derived from the [Wikilinks dataset](https://code.google.com/archive/p/wiki-links/) [announced by Google in 2013](https://research.googleblog.com/2013/03/learning-from-big-data-40-million.html). This dataset contains over 40M mentions of 3M distinct entities spanning 10M webpages. It provides entity resolutions by mapping each entity mention to a Wikipedia URL.
#
# Now, in order to do relation extraction, we actually need _pairs_ of entity mentions, and it's important to have the context around and between the two mentions. Fortunately, UMass has provided an [expanded version of Wikilinks](http://www.iesl.cs.umass.edu/data/data-wiki-links) which includes the context around each entity mention. We've written code to stitch together pairs of entity mentions along with their contexts, and we've filtered the examples extensively. The result is a compact corpus suitable for our purposes.
#
# Because we're frequently going to want to retrieve corpus examples containing specific entities, we've created a `Corpus` class which holds not only the examples themselves, but also a precomputed index. Let's take a closer look.

# %%
corpus = rel_ext.Corpus(os.path.join(rel_ext_data_home, 'example_inputs_long_names.tsv.gz'))

print('Read {0:,} examples'.format(len(corpus)))
# Out:
# Read 6,058 examples

# %% [markdown]
# Great, that's a lot of examples! Let's take a closer look at one.

# %%
print(corpus.examples[1])
# Out:
# Example(entity_1='Amazon.com Inc', entity_2='Netflix Inc', left='Other technology stocks in the FAANG group, Facebook, ', mention_1='Amazon.com Inc', middle=' and ', mention_2='Netflix Inc', right=', also weighed on the Nasdaq.', left_POS='Other technology stocks in the FAANG group, Facebook, ', mention_1_POS='Amazon.com Inc', middle_POS=' and ', mention_2_POS='Netflix Inc', right_POS=', also weighed on the Nasdaq.')

# %%
for element in corpus.examples[1]:
    print(element)
# Out:
# Amazon.com Inc
# Netflix Inc
# Other technology stocks in the FAANG group, Facebook,
# Amazon.com Inc
#  and
# Netflix Inc
# , also weighed on the Nasdaq.
# Other technology stocks in the FAANG group, Facebook,
# Amazon.com Inc
#  and
# Netflix Inc
# , also weighed on the Nasdaq.

# %% [markdown]
# Every example represents a fragment of webpage text containing two entity mentions. The first two fields, `entity_1` and `entity_2`, contain unique identifiers for the two entities mentioned. We name entities using Wiki IDs, which you can think of as the last portion of a Wikipedia URL. Thus the Wiki ID `Barack_Obama` designates the entity described by [https://en.wikipedia.org/wiki/Barack_Obama](https://en.wikipedia.org/wiki/Barack_Obama).
#
# The next five fields represent the text surrounding the two mentions, divided into five chunks: `left` contains the text before the first mention, `mention_1` is the first mention itself, `middle` contains the text between the two mentions, `mention_2` is the second mention, and the field `right` contains the text after the second mention. Thus, we can reconstruct the context as a single string like this:

# %%
ex = corpus.examples[1]

' '.join((ex.left, ex.mention_1, ex.middle, ex.mention_2, ex.right))
# Out:
# 'Other technology stocks in the FAANG group, Facebook,  Amazon.com Inc  and  Netflix Inc , also weighed on the Nasdaq.'

# %% [markdown]
# The last five fields contain the same five chunks of text, but this time annotated with part-of-speech (POS) tags, which may turn out to be useful when we start building models for relation extraction.
#
# Let's look at the distribution of entities over the corpus. How many entities are there, and what are the most common ones?

# %%
counter = Counter()
for example in corpus.examples:
    counter[example.entity_1] += 1
    counter[example.entity_2] += 1
print('The corpus contains {} entities'.format(len(counter)))
counts = sorted([(count, key) for key, count in counter.items()], reverse=True)
print('The most common entities are:')
for count, key in counts[:20]:
    print('{:10d} {}'.format(count, key))
# Out:
# The corpus contains 267 entities
# The most common entities are:
#       1271 Apple Inc
#        736 Qualcomm Inc
#        642 Boeing Co
#        537 Tesla Inc
#        452 Ford Motor Co
#        432 General Motors Co
#        346 Intel Corp
#        346 Huawei Technologies Co Ltd
#        288 Alphabet Inc
#        271 Amazon.com Inc
#        270 Microsoft Corp
#        265 Samsung Electronics Co Ltd
#        258 Toyota Motor Corp
#        251 AT&T Inc
#        230 T-Mobile US Inc
#        229 Panasonic Corp
#        227 Sprint Corp
#        223 Volkswagen AG
#        207 Chevron Corp
#        178 Spirit AeroSystems Holdings Inc

# %% [markdown]
# The main benefit we gain from the `Corpus` class is the ability to retrieve examples containing specific entities. Let's find examples containing `Elon_Musk` and `Tesla_Motors`.

# %%
corpus.show_examples_for_pair('Apple Inc', 'Corning Inc')
# Out:
# The first of 5 examples for Apple Inc and Corning Inc is:
# Example(entity_1='Apple Inc', entity_2='Corning Inc', left='', mention_1='Apple Inc', middle=' shares lost {AAPL.O;-PCTCHNG:2} percent as worries over softening demand for high-end smartphones were underscored as ', mention_2='Corning Inc', right=' reported a drop in screen glass sales for the first time in at least four quarters.', left_POS='', mention_1_POS='Apple Inc', middle_POS=' shares lost {AAPL.O;-PCTCHNG:2} percent as worries over softening demand for high-end smartphones were underscored as ', mention_2_POS='Corning Inc', right_POS=' reported a drop in screen glass sales for the first time in at least four quarters.')

# %% [markdown]
# Actually, this might not be all of the examples containing `Elon_Musk` and `Tesla_Motors`. It's only the examples where `Elon_Musk` was mentioned first and `Tesla_Motors` second. There may be additional examples that have them in the reverse order. Let's check.

# %%
corpus.show_examples_for_pair('Corning Inc', 'Apple Inc')
# Out:
# The first of 2 examples for Corning Inc and Apple Inc is:
# Example(entity_1='Corning Inc', entity_2='Apple Inc', left='', mention_1='Corning Inc', middle=' (GLW.N) on Tuesday reported a drop in sales at its screen glass unit for the first time in at least four quarters, and said it expects the weakness to spill into the current quarter, adding to growing market jitters about demand for high-end smartphones.Shares of the specialty glass maker, whose Gorilla glass became the screen of choice for many smartphones including ', mention_2='Apple Inc', right="'s (AAPL.O) iPhone and Samsung's (005930.KS) Galaxy, were down about 3 percent in morning trade.", left_POS='', mention_1_POS='Corning Inc', middle_POS=' (GLW.N) on Tuesday reported a drop in sales at its screen glass unit for the first time in at least four quarters, and said it expects the weakness to spill into the current quarter, adding to growing market jitters about demand for high-end smartphones.Shares of the specialty glass maker, whose Gorilla glass became the screen of choice for many smartphones including ', mention_2_POS='Apple Inc', right_POS="'s (AAPL.O) iPhone and Samsung's (005930.KS) Galaxy, were down about 3 percent in morning trade.")

# %% [markdown]
# Sure enough. Going forward, we'll have to remember to check both "directions" when we're looking for examples contains a specific pair of entities.
#
# This corpus is not without flaws. As you get more familiar with it, you will likely discover that it contains many examples that are nearly — but not exactly — duplicates. This seems to be a consequence of the web document sampling methodology that was used in the construction of the Wikilinks dataset. However, despite a few warts, it will serve our purposes.
#
# One thing this corpus does _not_ include is any annotation about relations. Thus, it could not be used for the fully-supervised approach to relation extraction, because the fully-supervised approach requires that each pair of entity mentions be annotated with the relation (if any) that holds between the two entities. In order to make any headway, we'll need to connect the corpus with an external source of knowledge about relations. We need a knowledge base.
#
# \[ [top](#Relation-extraction-using-distant-supervision:-task-definition) \]

# %% [markdown]
# ## The knowledge base

# %% [markdown]
# The data distribution for this unit includes a _knowledge base_ (KB) ultimately derived from [Freebase](https://en.wikipedia.org/wiki/Freebase). Unfortunately, Freebase was shut down in 2016, but the Freebase data is still available from various sources and in various forms. The KB included here was extracted from the [Freebase Easy data dump](http://freebase-easy.cs.uni-freiburg.de/dump/).
#
# The KB is a collection of *relational triples*, each consisting of a *relation*, a *subject*, and an *object*. For example, here are three triples from the KB:
#
# ```
# (place_of_birth, Barack_Obama, Honolulu)
# (has_spouse, Barack_Obama, Michelle_Obama)
# (author, The_Audacity_of_Hope, Barack_Obama)
# ```
#
# As you might guess:
#
# - The relation is one of a handful of predefined constants, such as `place_of_birth` or `has_spouse`.
# - The subject and object are entities represented by Wiki IDs (that is, suffixes of Wikipedia URLs).
#
# Now, just as we did for the corpus, we've created a `KB` class to store the KB triples and some associated indexes. This class makes it easy and efficient to look up KB triples both by relation and by entities.

# %%
kb = rel_ext.KB(os.path.join(rel_ext_data_home, 'example_kb.tsv.gz'))

print('Read {0:,} KB triples'.format(len(kb)))
# Out:
# Read 21,458 KB triples

# %% [markdown]
# Let's get a sense of the high-level characteristics of this KB. Some questions we'd like to answer:
#
# - How many relations are there?
# - How big is each relation?
# - Examples of each relation.
# - How many unique entities does the KB include?

# %%
len(kb.all_relations)
# Out:
# 2

# %% [markdown]
# How big is each relation? That is, how many triples does each relation contain?

# %%
for rel in kb.all_relations:
    print('{:12d} {}'.format(len(kb.get_triples_for_relation(rel)), rel))
# Out:
#        10044 customer of
#        11414 supplier of

# %% [markdown]
# Let's look at one example from each relation, so that we can get a sense of what they mean.

# %%
for rel in kb.all_relations:
    print(tuple(kb.get_triples_for_relation(rel)[0]))
# Out:
# ('customer of', 'Apple Inc', 'Seoul Semiconductor Co Ltd')
# ('supplier of', 'Iri Group Holdings Inc', 'DS Smith PLC')

# %% [markdown]
# The `kb.get_triples_for_entities()` method allows us to look up triples by the entities they contain. Let's use it to see what relation(s) hold between `France` and `Germany`.

# %%
kb.get_triples_for_entities('Apple Inc', 'Corning Inc')
# Out:
# [KBTriple(rel='customer of', sbj='Apple Inc', obj='Corning Inc')]

# %% [markdown]
# Relations like `adjoins` and `has_sibling` are intuitively symmetric — if the relation holds between _X_ and _Y_, then we expect it to hold between _Y_ and _X_ as well.

# %%
#Here we actually expect the inverse -> -100% correlation between both relations
kb.get_triples_for_entities('Corning Inc', 'Apple Inc')
# Out:
# [KBTriple(rel='supplier of', sbj='Corning Inc', obj='Apple Inc')]

# %% [markdown]
# However, there's no guarantee that all such inverse triples actually appear in the KB. (You could write some code to check.)
#
# Most relations, however, are intuitively asymmetric. Let's see what relation holds between `Tesla_Motors` and `Elon_Musk`.

# %%
#kb.get_triples_for_entities('Tesla_Motors', 'Elon_Musk')
# Out:
# [KBTriple(rel='founders', sbj='Tesla_Motors', obj='Elon_Musk')]

# %% [markdown]
# It's a bit arbitrary that the KB includes a given asymmetric relation rather than its inverse. For example, instead of the `founders` relation with triple `(founders, Tesla_Motors, Elon_Musk)`, we might have had a `founder_of` relation with triple `(founder_of, Elon_Musk, Tesla_Motors)`. It doesn't really matter.
#
# Although we don't have a `founder_of` relation, there might still be a relation between `Elon_Musk` and `Tesla_Motors`. Let's check.

# %%
#kb.get_triples_for_entities('Elon_Musk', 'Tesla_Motors')
# Out:
# [KBTriple(rel='worked_at', sbj='Elon_Musk', obj='Tesla_Motors')]

# %% [markdown]
# Aha, yes, that makes sense. So it can be the case that one relation holds between _X_ and _Y_, and a different relation holds between _Y_ and _X_.
#
# One more observation: there may be more than one relation that holds between a given pair of entities, even in one direction.

# %%
#kb.get_triples_for_entities('Cleopatra', 'Ptolemy_XIII_Theos_Philopator')
# Out:
# [KBTriple(rel='has_sibling', sbj='Cleopatra', obj='Ptolemy_XIII_Theos_Philopator'),
#  KBTriple(rel='has_spouse', sbj='Cleopatra', obj='Ptolemy_XIII_Theos_Philopator')]

# %% [markdown]
# No! What? Yup, it's true — [Cleopatra](https://en.wikipedia.org/wiki/Cleopatra) married her younger brother, [Ptolemy XIII](https://en.wikipedia.org/wiki/Ptolemy_XIII_Theos_Philopator). Wait, it gets worse — she also married her _even younger_ brother, [Ptolemy XIV](https://en.wikipedia.org/wiki/Ptolemy_XIV_of_Egypt). Apparently this was normal behavior in ancient Egypt.
#
# Moving on ...
#
# Let's look at the distribution of entities in the KB. How many entities are there, and what are the most common ones?

# %%
counter = Counter()
for kbt in kb.kb_triples:
    counter[kbt.sbj] += 1
    counter[kbt.obj] += 1
print('The KB contains {:,} entities'.format(len(counter)))
counts = sorted([(count, key) for key, count in counter.items()], reverse=True)
print('The most common entities are:')
for count, key in counts[:20]:
    print('{:10d} {}'.format(count, key))
# Out:
# The KB contains 8,460 entities
# The most common entities are:
#        915 Microsoft Corp
#        545 Apple Inc
#        540 Boeing Co
#        508 Google LLC
#        460 Samsung Electronics Co Ltd
#        424 Amazon.com Inc
#        412 Oracle Corp
#        411 AT&T Inc
#        396 International Business Machines Corp
#        383 Airbus SE
#        362 Cisco Systems Inc (Pre-Merger)
#        341 Huawei Technologies Co Ltd
#        338 BP PLC
#        325 Walmart Inc
#        324 Shell PLC
#        317 Intel Corp
#        304 Nokia Oyj
#        293 Ford Motor Co
#        284 Salesforce.Com Inc
#        268 Telefonaktiebolaget LM Ericsson

# %% [markdown]
# From Tim:
# Currenlty our News Corpus is v small so our entity count is low. We might want to check for some pre-written work on recognising corporate entities in news

# %% [markdown]
# The number of entities in the KB is less than half the number of entities in the corpus! Evidently the corpus has much broader coverage than the KB.
#
# Note that there is no promise or expectation that this KB is _complete_. Not only does the KB contain no mention of many entities from the corpus — even for the entities it does include, there may be possible triples which are true in the world but are missing from the KB. As an example, these triples are in the KB:
#
# ```
# (founders, SpaceX, Elon_Musk)
# (founders, Tesla_Motors, Elon_Musk)
# (worked_at, Elon_Musk, Tesla_Motors)
# ```
#
# but this one is not:
#
# ```
# (worked_at, Elon_Musk, SpaceX)
# ```
#
# In fact, the whole point of developing methods for automatic relation extraction is to extend existing KBs (and build new ones) by identifying new relational triples from natural language text. If our KBs were complete, we wouldn't have anything to do.
#
# \[ [top](#Relation-extraction-using-distant-supervision:-task-definition) \]

# %% [markdown]
# ## Problem formulation
#
# With our data assets in hand, it's time to provide a precise formulation of the prediction problem we aim to solve. We need to specify:
#
# - What is the input to the prediction?
#     - Is it a specific pair of entity *mentions* in a specific context?
#     - Or is it a pair of *entities*, apart from any specific mentions?
# - What is the output of the prediction?
#     - Do we need to predict at most one relation label? (This is [multi-class classification](https://en.wikipedia.org/wiki/Multiclass_classification).)
#     - Or can we predict multiple relation labels? (This is [multi-label classification](https://en.wikipedia.org/wiki/Multi-label_classification).)
#
# ### Joining the corpus and the KB
#
# In order to leverage the distant supervision paradigm, we'll need to connect information in the corpus with information in the KB. There are two possibilities, depending on how we formulate our prediction problem:
#
# - __Use the KB to generate labels for the corpus.__ If our problem is to classify a pair of entity *mentions* in a specific example in the corpus, then we can use the KB to provide labels for training examples. Labeling specific examples is how the fully supervised paradigm works, so it's the obvious way to think about leveraging distant supervision as well. Although it can be made to work, it's not actually the preferred approach.
# - __Use the corpus to generate features for entity pairs.__ If instead our problem is to classify a pair of *entities*, then we can use all the examples from the corpus where those two entities co-occur to generate a feature representation describing the entity pair. This is the approach taken by [Mintz et al. 2009](https://www.aclweb.org/anthology/P09-1113), and it's the approach we'll pursue here.
#
# So we'll formulate our prediction problem such that the input is a pair of entities, and the goal is to predict what relation(s) the pair belongs to. The KB will provide the labels, and the corpus will provide the features.
#
# We've created a `Dataset` class which combines a corpus and a KB, and provides a variety of convenience methods for the dataset.

# %%
dataset = rel_ext.Dataset(corpus, kb)

# %% [markdown]
# Let's determine how many examples we have for each triple in the KB. We'll compute averages per relation.

# %%
dataset.count_examples()
# Out:
#                                              examples
# relation               examples    triples    /triple
# --------               --------    -------    -------
# customer of                7500      10044       0.75
# supplier of                7817      11414       0.68

# %% [markdown]
# From Tim: We have waaaaay to little examples at the moment....not surprising we only took a few articles

# %% [markdown]
# For most relations, the total number of examples is fairly large, so we can be optimistic about learning what linguistic patterns express a given relation. However, for individual entity pairs, the number of examples is often quite low. Of course, more data would be better — much better! But more data could quickly become unwieldy to work with in a notebook like this.

# %% [markdown]
# ### Negative instances
#
# By joining the corpus to the KB, we can obtain abundant positive instances for each relation. But a classifier cannot be trained on positive instances alone. In order to apply the distant supervision paradigm, we will also need some negative instances — that is, entity pairs which do not belong to any known relation. If you like, you can think of these entity pairs as being assigned to a special relation called `NO_RELATION`. We can find plenty of such pairs by searching for examples in the corpus which contain two entities which do not belong to any relation in the KB.

# %% [markdown]
# Tim: We will need to amend this as we have created the news articles to be including pairs of companis we know that are linked

# %%
unrelated_pairs = dataset.find_unrelated_pairs()
print('Found {0:,} unrelated pairs, including:'.format(len(unrelated_pairs)))
for pair in list(unrelated_pairs)[:10]:
    print('   ', pair)
# Out:
# Found 22 unrelated pairs, including:
#     ('Lockheed Martin', 'Boeing Co')
#     ('Lockheed Martin', 'Airbus SE')
#     ('Mitsubishi Motors Corp', 'ANA Holdings Inc')
#     ('Dell Technologies Inc', 'Amazon.com Inc')
#     ('Amazon.com Inc', 'Dell Technologies Inc')
#     ('Mitsubishi Motors Corp', 'Marubeni Corp')
#     ('Northrop Grumman Corp', 'Lockheed Martin')
#     ('Airbus SE', 'Lockheed Martin')
#     ('ANA Holdings Inc', 'Mitsubishi Motors Corp')
#     ('Saab AB', 'Lockheed Martin')

# %% [markdown]
# That's a lot of negative instances! In fact, because these negative instances far outnumber our positive instances (that is, the triples in our KB), when we train models we'll wind up downsampling the negative instances substantially.
#
# Remember, though, that some of these supposedly negative instances may be false negatives. Our KB is not complete. A pair of entities might be related in real life even if they don't appear together in the KB.

# %% [markdown]
# ### Multi-label classification
#
# A given pair of entities can belong to more than one relation. In fact, this is quite common in our KB.

# %% [markdown]
# Tim: We should check that we dont have Company A customer of Company B AND Company A supplier of Company B...well maybe only for two large companies that might well be buying from / supplying different business lins

# %%
dataset.count_relation_combinations()
# Out:
# The most common relation combinations are:
#       1475 ('customer of', 'supplier of')

# %% [markdown]
# While a few of those combinations look like data errors, most look natural and intuitive. Multiple relations per entity pair is a commonplace phenomenon.
#
# This observation strongly suggests formulating our prediction problem as [multi-label classification](https://en.wikipedia.org/wiki/Multi-label_classification). We could instead treat it as [multi-class classification](https://en.wikipedia.org/wiki/Multiclass_classification) — and indeed, [Mintz et al. 2009](https://www.aclweb.org/anthology/P09-1113) did so — but if we do, we'll be faced with the problem of assigning a single relation label to entity pairs which actually belong to multiple relations. It's not obvious how best to do this (and Mintz et al. 2009 did not make their method clear).
#
# There are a number of ways to approach multi-label classification, but the most obvious is the [binary relevance method](https://en.wikipedia.org/wiki/Multi-label_classification#Problem_transformation_methods), which just factors multi-label classification over _n_ labels into _n_ independent binary classification problems, one for each label. A disadvantage of this approach is that, by treating the binary classification problems as independent, it fails to exploit correlations between labels. But it has the great virtue of simplicity, and it will suffice for our purposes.
#
# So our problem will be to take as input an entity pair and a candidate relation (label), and to return a binary prediction as to whether the entity pair belongs to the relation. Since a KB triple is precisely a relation and a pair of entities, we could say equivalently that our prediction problem amounts to binary classification of KB triples. Given a candidate KB triple, do we predict that it is valid?

# %% [markdown]
# ### Building datasets
#
# We're now in a position to write a function to build datasets suitable for training and evaluating predictive models. These datasets will have the following characteristics:
#
# - Because we've formulated our problem as multi-label classification, and we'll be training separate models for each relation, we won't build a single dataset. Instead, we'll build a dataset for each relation, and our return value will be a map from relation names to datasets.
# - The dataset for each relation will consist of two parallel lists:
#   - A list of candidate `KBTriples` which combine the given relation with a pair of entities.
#   - A corresponding list of boolean labels indicating whether the given `KBTriple` belongs to the KB.
# - The dataset for each relation will include `KBTriples` derived from two sources:
#   - Positive instances will be drawn from the KB.
#   - Negative instances will be sampled from unrelated entity pairs, as described above.

# %%
kbts_by_rel, labels_by_rel = dataset.build_dataset(
    include_positive=True, sampling_rate=0.1, seed=1)

# %%
kbts_by_rel
# Out:
# defaultdict(list,
#             {'customer of': [KBTriple(rel='customer of', sbj='Apple Inc', obj='Seoul Semiconductor Co Ltd'),
#               KBTriple(rel='customer of', sbj='Koizumi furnitech Thailand Co Ltd', obj='Seoul Semiconductor Co Ltd'),
#               KBTriple(rel='customer of', sbj='Amazon.com Inc', obj='DS Smith PLC'),
#               KBTriple(rel='customer of', sbj='Procter & Gamble Co', obj='DS Smith PLC'),
#               KBTriple(rel='customer of', sbj='Zymeworks Inc', obj='DS Smith PLC'),
#               KBTriple(rel='customer of', sbj='Nestle SA', obj='DS Smith PLC'),
#               KBTriple(rel='customer of', sbj='Unilever PLC', obj='DS Smith PLC'),
#               KBTriple(rel='customer of', sbj='SoftBank Group Corp', obj='Brightstar Corp'),
#               KBTriple(rel='customer of', sbj='Sprint Corp', obj='Brightstar Corp'),
#               KBTriple(rel='customer of', sbj='Total Access Communication PCL', obj='Brightstar Corp'),
#               KBTriple(rel='customer of', sbj='Blackridge Technology International Inc', obj='Brightstar Corp'),
#               KBTriple(rel='customer of', sbj='RBS Group', obj='Brightstar Corp'),
#               KBTriple(rel='customer of', sbj='Sprint Communications Inc', obj='Brightstar Corp'),
#               KBTriple(rel='customer of', sbj='Igloo Inc', obj='Brightstar Corp'),
#               KBTriple(rel='customer of', sbj='Volkswagen AG', obj='Navistar International Corp'),
#               KBTriple(rel='customer of', sbj='Workhorse Group Inc', obj='Navistar International Corp'),
#               KBTriple(rel='customer of', sbj='Beijing TuSimple Future Technology Co Ltd', obj='Navistar International Corp'),
#               KBTriple(rel='customer of', sbj='J B Hunt Transport Services Inc', obj='Navistar International Corp'),
#               KBTriple(rel='customer of', sbj='General Motors Co', obj='Navistar International Corp'),
#               KBTriple(rel='customer of', sbj='Ford Motor Co', obj='Navistar International Corp'),
#               KBTriple(rel='customer of', sbj='Aptiv PLC', obj='Navistar International Corp'),
#               KBTriple(rel='customer of', sbj='Heartland Express Inc', obj='Navistar International Corp'),
#               KBTriple(rel='customer of', sbj='Oshkosh Corp', obj='Navistar International Corp'),
#               KBTriple(rel='customer of', sbj='Anhui Jianghuai Automobile Group Corp Ltd', obj='Navistar International Corp'),
#               KBTriple(rel='customer of', sbj='FAW Jiefang Automotive Co Ltd', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Hyundai Motor Co', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Iveco Magirus AG', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='FCA US LLC', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Daimler Trucks North America LLC', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Mercedes Benz do Brasil Ltda', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Dongfeng Liuzhou Motor Co Ltd', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Yutong Bus Co Ltd', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Kgt 2010 Aps', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Geely Automobile Holdings Ltd', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Cummins Inc', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Kamaz PAO', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Ford Otomotiv Sanayi AS', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Meritor Inc', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Tata Motors Ltd', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='ZF Friedrichshafen AG', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Clean Vision Corp', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Mercedes-Benz Group AG', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Wabash National Corp', obj='WABCO Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Symmetry Electronics Corp', obj='TDK Corp'),
#               KBTriple(rel='customer of', sbj='Apple Inc', obj='TDK Corp'),
#               KBTriple(rel='customer of', sbj='Glassbridge Enterprises Inc', obj='TDK Corp'),
#               KBTriple(rel='customer of', sbj='Nubian Resources Ltd', obj='TDK Corp'),
#               KBTriple(rel='customer of', sbj='Boeing Co', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='El Al Israel Airlines Ltd', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='United Airlines Inc', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='DISH Network Corp', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='American Airlines Group Inc', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Japan Airlines Co Ltd', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Arianespace SASU', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Lockheed Martin Corp', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='United Airlines Holdings Inc', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Northrop Grumman Australia Pty Ltd', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Qantas Airways Ltd', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Icelandair Group hf', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Benchmark Electronics Inc', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Northrop Grumman Corp', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Bentley Motors Ltd', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='JetBlue Airways Corp', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Eutelsat Communications SA', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Malaysia Airlines Bhd', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Bombardier Inc', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Grupo Aeromexico SAB de CV', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='SS/L Holdings Inc', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Telesat Corp', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='KVH Industries Inc', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='RigNet Inc', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Dassault Aviation SA', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='Microsoft Corp', obj='ViaSat Inc'),
#               KBTriple(rel='customer of', sbj='BP PLC', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Petroleo Brasileiro SA Petrobras', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Shell PLC', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Iog PLC', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Saudi Arabian Oil Co', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Burullus Gas Company SAE', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Chevron Australia Pty Ltd', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='ExxonMobil Canada Ltd', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Hess Denmark ApS', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Mobil Producing Nigeria Unltd', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Dof Subsea AS', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Chevron Overseas (Congo) Ltd', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Centrica PLC', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Equinor ASA', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Aker BP ASA', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Shell International Ltd', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Turkiye Petrol Rafinerileri AS', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Vattenfall AB', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Tullow Oil PLC', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='TechnipFMC PLC', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Woodside Energy Ltd', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Murphy Oil Corp', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Dana Petroleum Ltd', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Woodside Petroleum Ltd', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Petroleo Brasileiro SA Petrobras', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Chevron Corp', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Talisman Enterprise Inc', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Cnooc Petroleum Europe Ltd', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Conocophillips', obj='Subsea 7 SA'),
#               KBTriple(rel='customer of', sbj='Mercedes-Benz Group AG', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='CWI Group SAS', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Navistar International Corp', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Revlon Consumer Products Corp', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Beijing TuSimple Future Technology Co Ltd', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='FCA US LLC', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Cummins India Ltd', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Daimler Trucks North America LLC', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Westport Fuel Systems Inc', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Boise Peterbilt Inc', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Volkswagen AG', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='USA Compression Partners LP', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Daimler Truck AG', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Filtration SAS', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='WABCO Holdings Inc', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Ballard Power Systems Inc', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Nissan Motor Co Ltd', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Revlon Inc', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Freightliner Ltd', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Korea Shipbuilding & Offshore Engineering Co Ltd', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Stellantis NV', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Scania AB', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Paccar Inc', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Ford Motor Co', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Kenworth de La Montana SAS', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Chrysler Ltd', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Volvo AB', obj='Cummins Inc'),
#               KBTriple(rel='customer of', sbj='Volkswagen AG', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='ZTE Corp', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='General Motors Co', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='AT&T Inc', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='China Mobile Ltd', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='Honda Motor Co Ltd', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='Porsche Automobil Holding SE', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='Inspirato LLC', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='Sprint Communications Inc', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='Sprint Corp', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='LG Corp', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='Apple Inc', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='Mercedes-Benz Group AG', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='LG Chem Ltd', obj='LG Electronics Inc'),
#               KBTriple(rel='customer of', sbj='Apple Inc', obj='Cowell e Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Samsung Electronics Co Ltd', obj='Cowell e Holdings Inc'),
#               KBTriple(rel='customer of', sbj='Indian Oiltanking Ltd', obj='Chunghwa Telecom Co Ltd'),
#               KBTriple(rel='customer of', sbj='Honda Motor Co Ltd', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Volkswagen AG', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Bayerische Motoren Werke AG', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Hyundai Motor Co', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Rimini Street Inc', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Kia Corp', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Altima Resources Ltd', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='General Motors Co', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Audi AG', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Hyundai Motor Group China Ltd', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Nissan Motor Co Ltd', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Ford Motor Co', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Porsche Automobil Holding SE', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Mercedes-Benz Group AG', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Scania AB', obj='Hankook & Company Co Ltd'),
#               KBTriple(rel='customer of', sbj='Exxon Mobil Corp', obj='Oil Search Ltd'),
#               KBTriple(rel='customer of', sbj='BP PLC', obj='Oil Search Ltd'),
#               KBTriple(rel='customer of', sbj='Png Lng Gas Project', obj='Oil Search Ltd'),
#               KBTriple(rel='customer of', sbj='Ampol Ltd', obj='Oil Search Ltd'),
#               KBTriple(rel='customer of', sbj='Polski Koncern Naftowy Orlen SA', obj="Transneft' PAO"),
#               KBTriple(rel='customer of', sbj='Mozyrskiy NPZ OAO', obj="Transneft' PAO"),
#               KBTriple(rel='customer of', sbj="NK Rosneft' PAO", obj="Transneft' PAO"),
#               KBTriple(rel='customer of', sbj='EMC Corp', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Dell A/S', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Botanix Pharmaceuticals Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Airlinq Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Kyndryl Luxembourg SARL', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Rackspace Technology Global Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Wyse Technology LLC', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Google LLC', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='AT&T Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='HP Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Nutanix Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Tabcorp Holdings Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Al Mawarid Bank SAL', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='American Internet Services Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Columbia Sportswear Co', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='LG Electronics Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Trend Micro Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Dell SARL', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='T Systems Spring Italia SRL', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Telekom Malaysia Bhd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='UB Bancorp', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='VITAS Healthcare Corp', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='STL Global Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='NetApp Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='United Overseas Bank Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Dell Technologies Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Microsoft Corp', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Fujitsu Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Amadeus IT Group SA', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='NortonLifeLock Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Sap It Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Flexential Colorado Corp', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Dell AB', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='SGB SMIT Management GmbH', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Indian Oiltanking Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='International Business Machines Corp', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Nippon Telegraph and Telephone Corp', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Citrix Systems Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Lenovo Group Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Calix Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Dell Ab Oy', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Millicom International Cellular SA', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Beck Disaster Recovery  Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Chris Richardson Consulting Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Singapore Airlines Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='HAPPIGO CLOUD PROVIDERS TRADING HONG KONG CO LTD', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Phoenix NAP LLC', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Vivo Mobile India Pvt Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='WAN SOLUTIONS INC', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Teradici Corp', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Hitachi Vantara Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Telefonica SA', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Equinix Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='McAfee LLC', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Laboratoriya Kasperskogo AO', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Virtustream LLC', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Mellanox Technologies Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Amazon Web Services Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Vodafone Group PLC', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='VMware vCloud Service GK', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='SoftBank Group Corp', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Juniper Networks Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='GE Healthcare Ltd', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='NTT Com Security AG', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Lumen Technologies Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Vuzix Corp', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Uber Technologies Inc', obj='VMware Inc'),
#               KBTriple(rel='customer of', sbj='Apple Inc', obj='Coxon Precise Industrial Co Ltd'),
#               KBTriple(rel='customer of', sbj='United Airlines Holdings Inc', obj='Copa Holdings SA'),
#               KBTriple(rel='customer of', sbj='Boeing Co', obj='Copa Holdings SA'),
#               KBTriple(rel='customer of', sbj='Google LLC', obj='Fitbit Inc'),
#               KBTriple(rel='customer of', sbj='Target Corp', obj='Fitbit Inc'),
#               KBTriple(rel='customer of', sbj='Alphabet Inc', obj='Fitbit Inc'),
#               KBTriple(rel='customer of', sbj='Scripps Research Institute', obj='Fitbit Inc'),
#               KBTriple(rel='customer of', sbj='Humana Inc', obj='Fitbit Inc'),
#               KBTriple(rel='customer of', sbj='Visa Inc', obj='Fitbit Inc'),
#               KBTriple(rel='customer of', sbj='Amazon.com Inc', obj='Fitbit Inc'),
#               KBTriple(rel='customer of', sbj='Apple Inc', obj='Fitbit Inc'),
#               KBTriple(rel='customer of', sbj='Mercedes-Benz Group AG', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Navistar International Corp', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Volvo AB', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Iveco Magirus AG', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Ashok Leyland Ltd', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Sypris Solutions Inc', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Oshkosh Corp', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Paccar Inc', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Scania AB', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Man Se', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Daimler Trucks North America LLC', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Hyliion Inc', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Wabash National Corp', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Ford Motor Co', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Manitowoc Company Inc', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Hexagon Purus ASA', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Schmitz Cargobull AG', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Hino Motors Manufacturing USA Inc', obj='Meritor Inc'),
#               KBTriple(rel='customer of', sbj='Deutsche Telekom AG', obj='Magyar Telekom Tavkozlesi Nyrt'),
#               KBTriple(rel='customer of', sbj='Alcatel-Lucent International SA', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Huawei Technologies Co Ltd', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Vodafone Group PLC', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='America Movil SAB de CV', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Rekor Recognition Systems Inc', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Verizon Communications Inc', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Alcatel-Lucent International Holdings Inc', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Lumentum Holdings Inc', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='AT&T Inc', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Nokia Networks', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Time Warner Inc', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Etihad Etisalat Company SJSC', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Historic TW Inc', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Telstra Corporation Ltd', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Rakuten Group Inc', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Reliance Industries Ltd', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Cisco Systems Inc', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='KLA Corp', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Amada Co Ltd', obj='Viavi Solutions Inc'),
#               KBTriple(rel='customer of', sbj='Apple Inc', obj='Shanghai Industrial Holdings Ltd'),
#               KBTriple(rel='customer of', sbj='Accenture PLC', obj='Avanade Inc'),
#               KBTriple(rel='customer of', sbj='Delta Air Lines Inc', obj='Avanade Inc'),
#               KBTriple(rel='customer of', sbj='Microsoft Corp', obj='Avanade Inc'),
#               KBTriple(rel='customer of', sbj='Apple Inc', obj='FIH Mobile Ltd'),
#               KBTriple(rel='customer of', sbj='Huawei Technologies Co Ltd', obj='FIH Mobile Ltd'),
#               KBTriple(rel='customer of', sbj='Xiaomi Corp', obj='FIH Mobile Ltd'),
#               KBTriple(rel='customer of', sbj='Nokia Oyj', obj='FIH Mobile Ltd'),
#               KBTriple(rel='customer of', sbj='Sony Mobile Communications AB', obj='FIH Mobile Ltd'),
#               KBTriple(rel='customer of', sbj='Motorola Mobility Holdings LLC', obj='FIH Mobile Ltd'),
#               KBTriple(rel='customer of', sbj='Sony Group Corp', obj='FIH Mobile Ltd'),
#               KBTriple(rel='customer of', sbj='Motorola Solutions Inc', obj='FIH Mobile Ltd'),
#               KBTriple(rel='customer of', sbj='Amling Donuts Inc', obj='Leaf Group Ltd'),
#               KBTriple(rel='customer of', sbj='Ehow Inc', obj='Leaf Group Ltd'),
#               KBTriple(rel='customer of', sbj='Google LLC', obj='Leaf Group Ltd'),
#               KBTriple(rel='customer of', sbj='Rightside Group Ltd', obj='Leaf Group Ltd'),
#               KBTriple(rel='customer of', sbj='Huawei Technologies Co Ltd', obj='SK Hynix Inc'),
#               KBTriple(rel='customer of', sbj='Sandisk LLC', obj='SK Hynix Inc'),
#               KBTriple(rel='customer of', sbj='Apple Inc', obj='SK Hynix Inc'),
#               KBTriple(rel='customer of', sbj='Netlist Inc', obj='SK Hynix Inc'),
#               KBTriple(rel='customer of', sbj='International Business Machines Corp', obj='SK Hynix Inc'),
#               KBTriple(rel='customer of', sbj='Rambus Inc', obj='SK Hynix Inc'),
#               KBTriple(rel='customer of', sbj='Robert Bosch GmbH', obj='SK Hynix Inc'),
#               KBTriple(rel='customer of', sbj='Intel Corp', obj='SK Hynix Inc'),
#               KBTriple(rel='customer of', sbj='Acm Research Inc', obj='SK Hynix Inc'),
#               KBTriple(rel='customer of', sbj='Asustek Computer Inc', obj='SK Hynix Inc'),
#               KBTriple(rel='customer of', sbj='Micron Technology Inc', obj='SK Hynix Inc'),
#               KBTriple(rel='customer of', sbj='Comcast Corp', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Netflix Inc', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='DHX Television Ltd', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Home Box Office Inc', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Espn', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Hulu LLC', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Dwa Holdings LLC', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='ESPN.COM', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Red Electrica de Espana SAU', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Lucasfilm Ltd', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Hasbro Inc', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Euro Disney SCA', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Amazon.com Inc', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Shanghai Oriental DreamWorks Film & Television Technology Co Ltd', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Marvel Characters BV', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Tfcf Corp', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Apple Inc', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Pixar', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Verizon Communications Inc', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='Sinclair Broadcast Group Inc', obj='TWDC Enterprises 18 Corp'),
#               KBTriple(rel='customer of', sbj='SK Hynix Inc', obj='Silicon Motion Technology Corp'),
#               KBTriple(rel='customer of', sbj='Samsung Electronics Co Ltd', obj='Silicon Motion Technology Corp'),
#               KBTriple(rel='customer of', sbj='King Yuan Electronics Co Ltd', obj='Silicon Motion Technology Corp'),
#               KBTriple(rel='customer of', sbj='Micron Technology Inc', obj='Silicon Motion Technology Corp'),
#               KBTriple(rel='customer of', sbj='Eastern Maine Medical Center', obj='Silicon Motion Technology Corp'),
#               KBTriple(rel='customer of', sbj='Dell Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='General Electric Co', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Lenovo Group Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Microsoft Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='International Business Machines Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Amazon Web Services Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Ultratech Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Vornado Asset Protection Trust Grantee (TRS) LLC', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Buyer Group International Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='FLIR Systems Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Toshiba Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Penguin Computing Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Saas Global Sdn Bhd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Red Hat Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Sony Group Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Immunomedics Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Huawei Technologies Co Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Samsung Electronics Co Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Dell Technologies Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Cloudera Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Baidu Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='ZTE Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Super Micro Computer Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='MediaTek Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='America Movil SAB de CV', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Tesla Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='SK Hynix Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Mavenir Systems Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Fujitsu Technology Solutions SA', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='DLT Solutions Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Salesforce.Com Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Sedlmayr Grund und Immobilien AG', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Quickfire Networks Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Mobileye BV', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Meta Platforms Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='AT&T Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Alphabet Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Luminar Group Holdings PLC', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Toyota Motor Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Bromium Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Honeywell International Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Insyde Software Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Rog Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='World Wide Technology Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Citrix Systems Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Google LLC', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='NVIDIA Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Acer Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Clean Energy And Power Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Oracle Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='American Industrial Systems Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='McAfee LLC', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Fujitsu Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='SVF Holdco (UK) Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='ARM Holdings Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='ASBISc Enterprises PLC', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Achronix Semiconductor Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Gigabyte Technology Co Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='GoTo Group Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='AAEON Technology Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Nuveen California Quality Income Municipal Fund Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='TDC Soft Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Bio-AMD Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Advanced Micro Devices Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Cisco Systems Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='NEC Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='William Lyon Homes', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Audi AG', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Motorola Mobility LLC', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Thales Esecurity Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='AMAX Information Technologies Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Intel Capital Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='FNB Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Waymo LLC', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Emulex Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='SPAR Group Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Xiaomi Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='5G Networks Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Amazon.com Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='HP Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Qualcomm Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Altera Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='CompuCom Systems Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='DISH Network Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='EMC Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Hewlett Packard Enterprise Co', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Nokia Oyj', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='VMware Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Century Entertainment International Holdings Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Telefonaktiebolaget LM Ericsson', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Silicom Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='GlobalFoundries Management Services LLC & Co KG', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Bharti Airtel Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='TD Synnex Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Fortinet Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Udelv Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='CEFC Hong Kong Financial Investment Company Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='II-VI Optoelectronic Devices Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Tencent Holdings Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Esl Steel Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Pro-Tech Industries Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Rakuten Group Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='SMS Audio LLC', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Alibaba Group Holding Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Bayerische Motoren Werke AG', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Netronome Systems Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Cyber Security 1 AB', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Applied Materials Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Mayne Pharma Ventures Pty Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Newegg Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Borqs Technologies Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='EMC PCL', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Western Digital Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Motorola Solutions Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Asustek Computer Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Wipro Ltd', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Supermicro System Corp', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Micron Technology Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Marvell Technology Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Aptiv PLC', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='ASML Holding NV', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='NEC Corporation of America', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='UL LLC', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Business Objects Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='OneSpan Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Rights Agent Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Adaptive Computing Enterprises Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='DDD Group PLC', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Spreadtrum Communications Inc', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Atipa Technologies', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Olympic Partners', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Depository Trust Co', obj='Intel Corp'),
#               KBTriple(rel='customer of', sbj='Hon Hai Precision Industry Co Ltd', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Roku Inc', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Lordstown Motors Corp', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Sharp Corp', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Xiaomi Corp', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Huawei Technologies Co Ltd', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Samsung Electronics Co Ltd', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Lenovo Group Ltd', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Toshiba Corp', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Tesla Inc', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Xiaomi Corp', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='BlackBerry Ltd', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Amazon.com Inc', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Fisker Inc', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Sony Group Corp', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Apple Inc', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Cisco Systems Inc', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Tencent Holdings Ltd', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Dell Inc', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Nokia Oyj', obj='Foxconn Technology Co Ltd'),
#               KBTriple(rel='customer of', sbj='Coca-Cola Co', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='EnergyAustralia Pty Ltd', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Air Malta PLC', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Fairview Health Services', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='B Braun Melsungen AG', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Evercore Inc', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj="McDonald's Corp", obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Verizon Communications Inc', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Persistent Systems Ltd', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Pilot Travel Centers LLC', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Spotify AB', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Unilever NV', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Mastercard Inc', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='JDA Partners LLC', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Salesforce.Com Inc', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Barclays PLC', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Unilever PLC', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Michaels Companies Inc', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Siemens AG', obj='Mulesoft LLC'),
#               KBTriple(rel='customer of', sbj='Points.com Inc', obj='Singapore Airlines Ltd'),
#               KBTriple(rel='customer of', sbj='Inmarsat Group Holdings Ltd', obj='Singapore Airlines Ltd'),
#               KBTriple(rel='customer of', sbj='Renault SA', obj='Avtovaz AO'),
#               KBTriple(rel='customer of', sbj='Nissan Motor Co Ltd', obj='Avtovaz AO'),
#               KBTriple(rel='customer of', sbj='LG Chem Ltd', obj='Ganfeng Lithium Co Ltd'),
#               KBTriple(rel='customer of', sbj='Tesla Inc', obj='Ganfeng Lithium Co Ltd'),
#               KBTriple(rel='customer of', sbj='Lithium Americas Corp', obj='Ganfeng Lithium Co Ltd'),
#               KBTriple(rel='customer of', sbj='Bacanora Lithium PLC', obj='Ganfeng Lithium Co Ltd'),
#               KBTriple(rel='customer of', sbj='Volkswagen AG', obj='Ganfeng Lithium Co Ltd'),
#               KBTriple(rel='customer of', sbj='Bayerische Motoren Werke AG', obj='Ganfeng Lithium Co Ltd'),
#               KBTriple(rel='customer of', sbj='SK Innovation Co Ltd', obj='PetroChina Co Ltd'),
#               KBTriple(rel='customer of', sbj='Chart Industries Inc', obj='PetroChina Co Ltd'),
#               KBTriple(rel='customer of', sbj='Ceylon Petroleum Corp', obj='PetroChina Co Ltd'),
#               KBTriple(rel='customer of', sbj='Vitol SA', obj='PetroChina Co Ltd'),
#               KBTriple(rel='customer of', sbj='Brightoil Petroleum (Holdings) Ltd', obj='PetroChina Co Ltd'),
#               KBTriple(rel='customer of', sbj='Shell PLC', obj='PetroChina Co Ltd'),
#               KBTriple(rel='customer of', sbj='Trafigura Pte Ltd', obj='PetroChina Co Ltd'),
#               KBTriple(rel='customer of', sbj='Unipec America Inc', obj='PetroChina Co Ltd'),
#               KBTriple(rel='customer of', sbj='Morgan Stanley', obj='PetroChina Co Ltd'),
# ...
#               KBTriple(rel='supplier of', sbj='Akka Technologies SE', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Adobe Inc', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='BorgWarner Morse Systems Japan KK', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Spirent Communications plc', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Dassault Systemes SE', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Lear Corp', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Google LLC', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Von Roll Holding AG', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Zhejiang Geely Holding Group Co Ltd', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='N Press Assembly Ltd', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Bulten AB', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='SAP SE', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Avtovaz AO', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Visteon Corp', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Vulcan Energy Corp', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Zebra Technologies Corp', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Exxon Mobil Corp', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Subros Ltd', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Acceleware Ltd', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Envision Group  The (Aka  Envision  Inc)', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Russkiye Avtobusy - Gruppa GAZ OOO', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Qualcomm Inc', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='AD Plastik dd', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='TomTom NV', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='STMicroelectronics NV', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Gentex Corp', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Linamar Light Metals SAS', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Sogefi SpA', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Continental AG', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Hyundai Rotem Co', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Parrot SA', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Publicis Groupe SA', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Valeo SE', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Airbus SE', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Ecovadis SAS', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Steel Strips Wheels Ltd', obj='Renault SA'),
#               KBTriple(rel='supplier of', sbj='Advanced Micro Devices Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='AU Optronics Corp', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Hon Hai Precision Industry Co Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='AT&T Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Neonode Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Sharp Corp', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Cloudability Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Frontier Smart Technologies Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Cincinnati Bell Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Jabil Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='ViXS Systems Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Blujay Solutions Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Cellco Partnership', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Worldpay Group Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Qualtrics LLC', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Contentguard Holdings Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Umicore SA', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Anavrin Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Magnolia Petroleum PLC', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='OmniVision Technologies Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Netsertive Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Starz Acquisition LLC', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Intel Corp', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='TiVo Corp', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='LG Display Co Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Taiwan Semiconductor Manufacturing Co Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Tata Consultancy Services Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Panzura Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Sensu Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='TV Market', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Macronix International Co Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Accenture PLC', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Atmel Corp', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Sony Electronics Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Wow Unlimited Media Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Sony Mobile Communications AB', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Steelwedge Software Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Anaqua Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Datameer Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Orange Business Services Trading Solutions', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Troika Media Group Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Amazon.com Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='JD.Com Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Samsung Electronics Co Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Qualcomm Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='BE Semiconductor Industries NV', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Wistron Corp', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Foxconn Technology Co Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Boku Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Zemoga', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Zoran Corp', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Halogen Software Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Audible Magic Corp', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Vtex Brasil Tecnologia para E-Commerce Ltda', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='FIH Mobile Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='TomTom NV', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Google LLC', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Volex PLC', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Equilibrium Solutions Corp', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Pegatron Corp', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Omnifone Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Neulion LLC', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Obducat AB', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='TikTok', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Reevoo Ltd', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Microsoft Corp', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Vodafone Group PLC', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='retarus GmbH', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Synchronoss Technologies Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Koninklijke Philips NV', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Valcom Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Corning Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='E Ink Holdings Inc', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Moroch Partners', obj='Sony Group Corp'),
#               KBTriple(rel='supplier of', sbj='Sivers Semiconductors AB', obj='Fujikura Ltd'),
#               KBTriple(rel='supplier of', sbj='Data Respons ASA', obj='NOK Corp'),
#               KBTriple(rel='supplier of', sbj='Liontown Resources Ltd', obj='LG Energy Solution Ltd'),
#               KBTriple(rel='supplier of', sbj='Bharti Airtel Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Synchronoss Technologies Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Telefonaktiebolaget LM Ericsson', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Samsung Electronics Co Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='CityFibre Infrastructure Holdings Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Vodafone Idea Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Parallel Wireless Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Optiva Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Syniverse Holdings Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='TiVo Solutions Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Viavi Solutions Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Piksel Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Synamedia', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Nokia Siemens Networks Mea FZ-LLC', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='TPG Corporation Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Deutsche Telekom AG', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Incap Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Indus Towers Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Casa Systems Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Kabel Deutschland Holding AG', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Virgin Media Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='NEC Corp', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Tricentis Technology & Consulting GmbH', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Arrow Electronics Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='EMC Corp', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Inclex No 1 Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Apple Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Comcast Corp', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='HireVue Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Softlab SpA', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Qualcomm Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='International Business Machines Corp', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Mitie Group PLC', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='TiVo Corp', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='VMware Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Ciena Corp', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='E2open LLC', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Kudelski SA', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Cisco Systems Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Actual Experience PLC', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Intec Telecom Systems Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Mavenir Systems Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Netscout Systems Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Dinglong Culture Co Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Huawei Technologies Co Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Pareteum Corp', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Celonis GmbH', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Dell Technologies Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Vodafone Global Enterprise Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Red Hat Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Gemalto BV', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Nuance Communications Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Amazon Web Services Inc', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Thales SA', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Gamma Telecom Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Orange SA', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Telstra Corporation Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Verizon UK Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Servcorp Ltd', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Cellco Partnership', obj='Vodafone Group PLC'),
#               KBTriple(rel='supplier of', sbj='Liberty Global PLC', obj='Vodafone Group PLC'),
#               ...],
#              'adjoins': [],
#              'supplier_of': []})

# %%
labels_by_rel
# Out:
# defaultdict(list,
#             {'customer of': [True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               ...],
#              'supplier of': [True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               True,
#               ...]})

# %%
print(kbts_by_rel['customer of'][0], labels_by_rel['customer of'][0])
# Out:
# KBTriple(rel='customer of', sbj='Apple Inc', obj='Seoul Semiconductor Co Ltd') True

# %%
print(kbts_by_rel['supplier of'][637], labels_by_rel['supplier of'][637])
# Out:
# KBTriple(rel='supplier of', sbj='P10 Inc', obj='HP Inc') True

# %% [markdown]
# \[ [top](#Relation-extraction-using-distant-supervision:-task-definition) \]

# %% [markdown]
# ## Evaluation
#
# Before we start building models, let's set up a test harness that allows us to measure a model's performance. This may seem backwards, but it's analogous to the software engineering paradigm of [test-driven development](https://en.wikipedia.org/wiki/Test-driven_development): first, define success; then, pursue it.

# %% [markdown]
# ### Splitting the data
#
# Whenever building a model from data, it's good practice to partition the data into a multiple _splits_ — minimally, a training split on which to train the model, and a test split on which to evaluate it. In fact, we'll go a bit further, and define three splits:
#
# - __The `tiny` split (1%).__ It's often useful to carve out a tiny chunk of data to use in place of training or test data during development. Of course, any quantitative results obtained by evaluating on the `tiny` split are nearly meaningless, but because evaluations run extremely fast, using this split is a good way to flush out bugs during iterative cycles of code development.
# - __The `train` split (74%).__ We'll use the majority of our data for training models, both during development and at final evaluation. Experiments with the `train` split may take longer to run, but they'll have much greater statistical power.
# - __The `dev` split (25%).__ We'll use the `dev` split as test data for intermediate (formative) evaluations during development. During routine experiments, all evaluations should use the `dev` split.
#
# You could also carve out a `test` split for a final (summative) evaluation at the conclusion of your work. The bake-off will have its own test set, so you needn't do this, but this is an important step for projects without pre-defined test splits.
#
# Splitting our data assets is somewhat more complicated than in many other NLP problems, because we have both a corpus and KB. In order to minimize leakage of information from training data into test data, we'd like to split both the corpus and the KB. And in order to maximize the value of a finite quantity of data, we'd like to align the corpus splits and KB splits as closely as possible. In an ideal world, each split would have its own hermetically-sealed universe of entities, the corpus for that split would contain only examples mentioning those entities, and the KB for that split would contain only triples involving those entities. However, that ideal is not quite achievable in practice. In order to get as close as possible, we'll follow this plan:
#
# - First, we'll split the set of entities which appear as the subject in some KB triple.
# - Then, we'll split the set of KB triples based on their subject entity.
# - Finally, we'll split the set of corpus examples.
#   - If the first entity in the example has already been assigned to a split, we'll assign the example to the same split.
#   - Alternatively, if the second entity has already been assigned to a split, we'll assign the example to the same split.
#   - Otherwise, we'll assign the example to a split randomly.
#
# <!-- \[ TODO: figure out whether we actually need to split the _corpus_ -- any lift from testing on train corpus? \] -->
#
# The `Dataset` method `build_splits` handles all of this:

# %%
splits = dataset.build_splits(
    split_names=['tiny', 'train', 'dev'],
    split_fracs=[0.01, 0.74, 0.25],
    seed=1)

splits
# Out:
# {'tiny': Corpus with 136 examples; KB with 244 triples,
#  'train': Corpus with 4,732 examples; KB with 15,632 triples,
#  'dev': Corpus with 1,190 examples; KB with 5,582 triples,
#  'all': Corpus with 6,058 examples; KB with 21,458 triples}

# %% [markdown]
# So now we can use `splits['train'].corpus` to refer to the training corpus, or `splits['dev'].kb` to refer to the dev KB.

# %% [markdown]
# ### Choosing evaluation metrics
#
# Because we've formulated our prediction problem as a family of binary classification problems, one for each relation (label), choosing evaluation metrics is pretty straightforward. The standard metrics for evaluating binary classification are [precision and recall](https://en.wikipedia.org/wiki/Precision_and_recall), which are more meaningful than simple accuracy, particularly in problems with a highly biased label distribution (like ours). We'll compute and report precision and recall separately for each relation (label). There are only two wrinkles:
#
# 1. __How best to combine precision and recall into a single metric.__ Having two evaluation metrics is often inconvenient. If we're considering a change to our model which improves precision but degrades recall, should we take it? To drive an iterative development process, it's useful to have a single metric on which to hill-climb. For binary classification, the standard answer is the [F<sub>1</sub>-score](https://en.wikipedia.org/wiki/F1_score), which is the harmonic mean of precision and recall. However, the F<sub>1</sub>-score gives equal weight to precision and recall. For our purposes, precision is probably more important than recall. If we're extracting new relation triples from (massively abundant) text on the web in order to augment a knowledge base, it's probably more important that the triples we extract are correct (precision) than that we extract all the triples we could (recall). Accordingly, instead of the F<sub>1</sub>-score, we'll use the F<sub>0.5</sub>-score, which gives precision twice as much weight as recall.
#
# 1. __How to aggregate metrics across relations (labels).__ Reporting metrics separately for each relation is great, but in order to drive iterative development, we'd also like to have summary metrics which aggregate across all relations. There are two possible ways to do it: _micro-averaging_ will give equal weight to all problem instances, and thus give greater weight to relations with more instances, while _macro-averaging_ will give equal weight to all relations, and thus give lesser weight to problem instances in relations with more instances. Because the number of problem instances per relation is, to some degree, an accident of our data collection methodology, we'll choose macro-averaging.
#
# Thus, while every evaluation will report lots of metrics, when we need a single metric on which to hill-climb, it will be the macro-averaged F<sub>0.5</sub>-score.

# %% [markdown]
# ### Running evaluations
#
# It's time to write some code to run evaluations and report results. This is now straightforward. The `rel_ext.evaluate()` function takes as inputs:
#
# - `splits`: a `dict` mapping split names to `Dataset` instances
# - `classifier`, which is just a function that takes a list of `KBTriples` and returns a list of boolean predictions
# - `test_split`, the split on which to evaluate the classifier, `dev` by default
# - `verbose`, a boolean indicating whether to print output

# %% [markdown]
# ### Evaluating a random-guessing strategy
#
# In order to validate our evaluation framework, and to set a floor under expected results for future evaluations, let's implement and evaluate a random-guessing strategy. The random guesser is a classifier which completely ignores its input, and simply flips a coin.

# %%
def lift(f):
    return lambda xs: [f(x) for x in xs]

def make_random_classifier(p=0.50):
    def random_classify(kb_triple):
        return random.random() < p
    return lift(random_classify)

# %%
rel_ext.evaluate(splits, make_random_classifier())
# Out:
# relation              precision     recall    f-score    support       size
# ------------------    ---------  ---------  ---------  ---------  ---------
# customer of               0.998      0.492      0.827       2557       2560
# supplier of               0.999      0.502      0.834       3025       3028
# ------------------    ---------  ---------  ---------  ---------  ---------
# macro-average             0.998      0.497      0.830       5582       5588
# 0.8304540789208608

# %% [markdown]
# The results are not too surprising. Recall is generally around 0.50, which makes sense: on any given example with label `True`, we are 50% likely to guess the right label. But precision is very poor, because most labels are not `True`, and because our classifier is completely ignorant of the features of specific problem instances. Accordingly, the F<sub>0.5</sub>-score is also very poor — first because even the equally-weighted F<sub>1</sub>-score is always closer to the lesser of precision and recall, and second because the F<sub>0.5</sub>-score weights precision twice as much as recall.
#
# Actually, the most remarkable result in this table is the comparatively good performance for the `contains` relation! What does this result tell us about the data?
#
# \[ [top](#Relation-extraction-using-distant-supervision:-task-definition) \]

# %% [markdown]
# ## A simple baseline model
#
# It shouldn't be too hard to do better than random guessing. But for now, let's aim low — let's use the data we have in the easiest and most obvious way, and see how far that gets us.
#
# We start from the intuition that the words between two entity mentions frequently tell us how they're related. For example, in the phrase "SpaceX was founded by Elon Musk", the words "was founded by" indicate that the `founders` relation holds between the first entity mentioned and the second. Likewise, in the phrase "Elon Musk established SpaceX", the word "established" indicates the `founders` relation holds between the second entity mentioned and the first.
#
# So let's write some code to find the most common phrases that appear between the two entity mentions for each relation. As the examples illustrate, we need to make sure to consider both directions: that is, where the subject of the relation appears as the first mention, and where it appears as the second.

# %%
def find_common_middles(split, top_k=3, show_output=False):
    corpus = split.corpus
    kb = split.kb
    mids_by_rel = {
        'fwd': defaultdict(lambda: defaultdict(int)),
        'rev': defaultdict(lambda: defaultdict(int))}
    for rel in kb.all_relations:
        for kbt in kb.get_triples_for_relation(rel):
            for ex in corpus.get_examples_for_entities(kbt.sbj, kbt.obj):
                mids_by_rel['fwd'][rel][ex.middle] += 1
            for ex in corpus.get_examples_for_entities(kbt.obj, kbt.sbj):
                mids_by_rel['rev'][rel][ex.middle] += 1
    def most_frequent(mid_counter):
        return sorted([(cnt, mid) for mid, cnt in mid_counter.items()], reverse=True)[:top_k]
    for rel in kb.all_relations:
        for dir in ['fwd', 'rev']:
            top = most_frequent(mids_by_rel[dir][rel])
            if show_output:
                for cnt, mid in top:
                    print('{:20s} {:5s} {:10d} {:s}'.format(rel, dir, cnt, mid))
            mids_by_rel[dir][rel] = set([mid for cnt, mid in top])
    return mids_by_rel

_ = find_common_middles(splits['train'], show_output=True)
# Out:
# customer of          fwd          163  and
# customer of          fwd           82 ,
# customer of          fwd           26  supplier
# customer of          rev           65  and
# customer of          rev           64 ,
# customer of          rev           12  (XOM.N) and
# supplier of          fwd          153  and
# supplier of          fwd          107 ,
# supplier of          fwd           17
# supplier of          rev           81  and
# supplier of          rev           48 ,
# supplier of          rev           22  supplier

# %% [markdown]
# A few observations here:
#
# - Some of the most frequent middles are natural and intuitive. For example, ", son of" indicates a forward `parents` relation, while "and his son" indicates a reverse `parents` relation.
# - Punctuation and stop words such as "and" and "of" are extremely common. Unlike some other NLP applications, it's probably a bad idea to throw these away — they carry lots of useful information.
# - However, punctuation and stop words tend to be highly ambiguous. For example, a bare comma is a likely middle for almost every relation in at least one direction.
# - A few of the results reflect quirks of the dataset. For example, the appearance of the phrase "in 1994 , he became a central figure in the" as a common middle for the `genre` relation reflects both the relative scarcity of examples for that relation, and an unfortunate tendency of the Wikilinks dataset to include duplicate or near-duplicate source documents. (That middle connects the entities [Ready to Die](https://en.wikipedia.org/wiki/Ready_to_Die) — the first studio album by the Notorious B.I.G. — and [East Coast hip hop](https://en.wikipedia.org/wiki/East_Coast_hip_hop).)
#
# Now it's straightforward task to build and evaluate a classifier which predicts `True` for a candidate `KBTriple` just in case its entities appear in the corpus connected by one of the phrases we just discovered.

# %%
def train_top_k_middles_classifier(top_k=3):
    split = splits['train']
    corpus = split.corpus
    top_k_mids_by_rel = find_common_middles(split=split, top_k=top_k)
    def classify(kb_triple):
        fwd_mids = top_k_mids_by_rel['fwd'][kb_triple.rel]
        rev_mids = top_k_mids_by_rel['rev'][kb_triple.rel]
        for ex in corpus.get_examples_for_entities(kb_triple.sbj, kb_triple.obj):
            if ex.middle in fwd_mids:
                return True
        for ex in corpus.get_examples_for_entities(kb_triple.obj, kb_triple.sbj):
            if ex.middle in rev_mids:
                return True
        return False
    return lift(classify)

# %%
rel_ext.evaluate(splits, train_top_k_middles_classifier())
# Out:
# relation              precision     recall    f-score    support       size
# ------------------    ---------  ---------  ---------  ---------  ---------
# customer of               1.000      0.008      0.040       2557       2560
# supplier of               1.000      0.007      0.032       3025       3028
# ------------------    ---------  ---------  ---------  ---------  ---------
# macro-average             1.000      0.007      0.036       5582       5588
# 0.03598189335640564

# %% [markdown]
# Not surprisingly, the performance of even this extremely simplistic model is noticeably better than random guessing. Of course, recall is much worse across the board, but precision and F<sub>0.5</sub>-score are sometimes much better. We observe big gains especially on `adjoins`, `author`, `has_sibling`, and `has_spouse`. Then again, at least one relation actually got worse. (Can you offer any explanation for that?)
#
# Admittedly, performance is still not great in absolute terms. However, we should have modest expectations for performance on this task — we are unlikely ever to get anywhere near perfect precision with perfect recall. Why?
#
# - High precision will be hard to achieve because the KB is incomplete: some entity pairs that are related in the world — and in the corpus — may simply be missing from the KB.
# - High recall will be hard to achieve because the corpus is finite: some entity pairs that are related in the KB may not have any examples in the corpus.
#
# Because of these unavoidable obstacles, what matters is not so much absolute performance, but relative performance of different approaches.
#
# __Question:__ What's the optimal value for `top_k`, the number of most frequent middles to consider? What choice maximizes our chosen figure of merit, the macro-averaged F<sub>0.5</sub>-score?
#
# \[ [top](#Relation-extraction-using-distant-supervision:-task-definition) \]
